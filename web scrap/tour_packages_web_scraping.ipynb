# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup 
import re
# Out:
# C:\Users\HARSHIT JAIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cities = [  'araku-valley',
 'visakhapatnam',
 'amaravathi',
 'gandikota',
 'tirupati',
 'vijayawada',
 'anantapur',
 'srisailam',
 'ananthagiri-hills',
 'kurnool',
 'guntur',
 'nellore',
 'lepakshi',
 'rajahmundry',
 'horsley-hills',
 'rollapadu-wildlife-sanctuary',
 'lambasingi',
 'chittoor',
 'borra-caves',
 'bhavani-island',
 'machilipatnam',
 'kakinada',
 'konaseema',
 'srikalahasti',
 'mantralayam',
 'annavaram',
 'puttaparthi',
 'vizianagaram',
 'samalkot',
 'nagarjunakonda',
 'yaganti',
 'rushikonda-beach',
 'coringa-wildlife-sanctuary',
 'maredumilli',
 'draksharamam',
 'oravakallu-rock-garden',
 'ahobilam-temple',
 'rayadurg',
 'kaigal-falls',
 'tadipatri',
 'nagalapuram',
 'chirala-beach',
 'tawang',
 'ziro',
 'namdapha-national-park',
 'sela-pass',
 'bomdila',
 'roing',
 'itanagar',
 'tezu',
 'dirang',
 'pasighat',
 'aalo',
 'nuranang-falls',
 'tawang-monastery',
 'bhalukpong',
 'sangti-valley',
 'namsai',
 'bum-la-pass',
 'changlang',
 'damro',
 'madhuri-lake',
 'anini',
 'mechuka',
 'daporijo',
 'pakhui-wildlife-sanctuary',
 'gorichen-peak',
 'golden-pagoda',
 'tirap',
 'khonsa',
 'yingkiong',
 'anjaw',
 'yupia',
 'kaziranga-national-park',
 'majuli',
 'guwahati',
 'manas-national-park',
 'dibrugarh',
 'jorhat',
 'hajo',
 'bogamati',
 'mayong',
 'dibru-saikhowa-national-park',
 'pobitora-wildlife-sanctuary',
 'barpeta',
 'umananda-island',
 'nameri-national-park',
 'tinsukia',
 'sivasagar',
 'diphu',
 'silchar',
 'goalpara',
 'dispur',
 'sualkuchi',
 'orang-national-park',
 'lilabari',
 'karimganj',
 'bongaigaon',
 'hailakandi',
 'dhemaji',
 'nalbari',
 'darrang',
 'morigaon',
 'nagaon',
 'sadiya',
 'digboi',
 'haflong',
 'tezpur',
 'bodh-gaya',
 'patna',
 'nalanda',
 'vaishali',
 'rajgir',
 'madhubani',
 'sitamarhi',
 'valmiki-national-park',
 'bhagalpur',
 'pawapuri',
 'hajipur',
 'muzaffarpur',
 'lauriya-nandangarh',
 'chhat-puja',
 'tomb-of-sher-shah-suri',
 'navlakha-palace',
 'jal-mandir',
 'mundeshwari-temple',
 'barnawapara-wildlife-sanctuary',
 'raipur',
 'jagdalpur',
 'charre-marre-waterfalls',
 'sirpur',
 'mainpat',
 'madku-dweep',
 'dhamtari',
 'bhilai',
 'chitrakote-falls',
 'indravati-national-park',
 'chirmiri',
 'tirathgarh-falls',
 'dantewada',
 'ghatarani-waterfalls',
 'bhoramdeo-temple',
 'malhar',
 'rajim',
 'guru-ghasidas-sanjay-national-park',
 'kanger-ghati-national-park',
 'purkhauti-muktangan',
 'achanakmar-wildlife-sanctuary',
 'calangute-beach',
 'fort-aguada',
 'cruise-in-goa',
 'water-sports-in-goa',
 'dudhsagar-falls',
 'anjuna-beach',
 'chapora-fort',
 'baga-beach',
 'palolem-beach',
 'varca-beach',
 'colva-beach',
 'benaulim-beach',
 'candolim-beach',
 'miramar-beach',
 'donapaula-bay',
 'agonda-beach',
 'butterfly-beach',
 'st-francis-church',
 'se-cathedral',
 'goa-state-museum',
 'sri-mangeshi-temple',
 'udaygiri',
 'sinquerim-fort',
 'corjuem-fort',
 'cab-de-rama-fort',
 'trevor’s-bar',
 'goa-veterinary-hospital',
 'dwarka',
 'somnath',
 'gir-national-park',
 'diu',
 'surat',
 'vadodara',
 'ahmedabad',
 'junagadh',
 'rajkot',
 'gandhinagar',
 'jamnagar',
 'bhavnagar',
 'porbandar',
 'kutch',
 'saputara',
 'daman',
 'silvassa',
 'champaner',
 'dholavira',
 'modhera',
 'faridabad',
 'gurgaon',
 'hisar',
 'rohtak',
 'panipat',
 'karnal',
 'ambala',
 'pinjore',
 'kurukshetra',
 'yamunanagar',
 'sonipat',
 'jind',
 'bhiwani',
 'bahadurgarh',
 'jhajjar',
 'manali',
 'shimla',
 'kasol',
 'mcleodganj',
 'dharamshala',
 'spiti-valley',
 'kasauli',
 'dalhousie',
 'kullu',
 'bir-billing',
 'chail',
 'khajjiar',
 'kufri',
 'parvati-valley',
 'tirthan-valley',
 'jibhi',
 'sethan-valley',
 'kaza',
 'triund',
 'malana',
 'tosh',
 'palampur',
 'narkanda',
 'prashar-lake-trek',
 'sissu',
 'naggar',
 'sarahan',
 'jispa',
 'kalpa',
 'fagu',
 'kinnaur',
 'kangra',
 'keylong',
 'rohtang-pass',
 'shoghi',
 'chamba',
 'tattapani',
 'mandi',
 'manikaran-sahib',
 'indravati-pass-trek',
 'nahan',
 'shoja',
 'deoghar',
 'jamshedpur',
 'ranchi',
 'betla-national-park',
 'ghatshila',
 'shikharji',
 'dasham-falls',
 'netarhat',
 'massanjore-dam',
 'hazaribagh',
 'bokaro-steel-city',
 'dhanbad',
 'parasnath-hills',
 'rajrappa',
 'jubilee-park',
 'hundru-falls',
 'jonha-falls',
 'dassam-falls',
 'usri-falls',
 'palkot-wildlife-sanctuary',
 'chandil-dam',
 'dimna-lake',
 'getalsud-dam',
 'topchanchi-lake',
 'khandoli-dam',
 'maithon-dam',
 'tagore-hill',
 'naulakha-temple',
 'sun-temple',
 'jagannath-temple',
 'ranchi-lake',
 'birsa-munda-zoological-park',
 'deori-temple',
 'rock-garden',
 'baidyanath-dham',
 'basukinath',
 'lodh-falls',
 'saranda-forest',
 'chota-nagpur-plateau',
 'coorg',
 'badami',
 'mysore',
 'hampi',
 'gokarna',
 'udupi',
 'chikmagalur',
 'jog-falls',
 'murudeshwar',
 'bangalore',
 'dandeli',
 'bandipur-national-park',
 'nagarhole-national-park',
 'kabini',
 'kemmanagundi',
 'thirthahalli',
 'kudremukh',
 'shravanabelagola',
 'pattadakal',
 'shimoga-shivamogga',
 'devbagh',
 'nandi-hills',
 'karwar',
 'halebidu',
 'bijapur',
 'shivagange',
 'maravanthe',
 'mangalore',
 'srirangapatna',
 'savandurga',
 'chikkaballapur',
 'honnemaradu',
 'anthargange',
 'bheemeshwari',
 'dubare',
 'dharmasthala',
 'kundapura',
 'br-hills',
 'sringeri',
 'shivanasamudra-falls',
 'aihole',
 'bidar',
 'belgaum',
 'gokak-falls',
 'patgaon',
 'munnar',
 'kochi',
 'alleppey',
 'wayanad',
 'varkala',
 'kumarakom',
 'kumbalangi',
 'vagamon',
 'kovalam',
 'periyar-national-park',
 'idukki',
 'kozhikode',
 'poovar',
 'sabarimala',
 'vythiri',
 'thekkady',
 'bekal',
 'thrissur',
 'palakkad',
 'thalassery',
 'nelliyampathy',
 'nilambur',
 'ponmudi',
 'trivandrum',
 'kalpetta',
 'kollam',
 'peerumedu',
 'guruvayur',
 'malampuzha',
 'kannur',
 'kasaragod',
 'thenmala',
 'kottayam',
 'silent-valley-national-park',
 'kumily',
 'ponnani',
 'pathanamthitta',
 'ernakulam',
 'thattekad-bird-sanctuary',
 'muthanga-wildlife-sanctuary',
 'malappuram',
 'devikulam',
 'bhopal',
 'indore',
 'ujjain',
 'gwalior',
 'jabalpur',
 'sanchi',
 'khajuraho',
 'kanha-national-park',
 'bandhavgarh-national-park',
 'pench-national-park',
 'satpura-national-park',
 'amarkantak',
 'dhuandhar-falls',
 'bhimbetka',
 'maheshwar',
 'mandu',
 'omkareshwar',
 'pachmarhi',
 'tawa-dam',
 'udaygiri',
 'sagar',
 'chanderi',
 'orchha',
 'shivpuri',
 'guna',
 'neemuch',
 'mandsaur',
 'ratlam',
 'vidisha',
 'rewa',
 'satna',
 'sidhi',
 'singrauli',
 'shajapur',
 'sheopur',
 'shivni',
 'sehore',
 'seoni',
 'harda',
 'hoshangabad',
 'dhar',
 'dindori',
 'damoh',
 'chhindwara',
 'betul',
 'burhanpur',
 'ashoknagar',
 'anuppur',
 'alirajpur',
 'khandwa',
 'khargone',
 'katni',
 'jhabua',
 'shyopur',
 'narsinghpur',
 'neemuch',
 'mumbai',
 'pune',
 'nashik',
 'aurangabad',
 'nagpur',
 'mahabaleshwar',
 'lonavala',
 'khandala',
 'matheran',
 'ajanta-caves',
 'ellora-caves',
 'elephanta-caves',
 'tadoba-national-park',
 'pench-national-park',
 'sinhagad-fort',
 'raigad-fort',
 'shirdi',
 'shani-shingnapur',
 'trimbakeshwar',
 'grishneshwar',
 'aundha-nagnath',
 'parli-vaijnath',
 'vajreshwari',
 'malshej-ghat',
 'bhimashankar',
 'saputara',
 'toranmal',
 'chikhaldara',
 'panvel',
 'alibaug',
 'murud-janjira',
 'dapoli',
 'imphal',
 'loktak-lake',
 'kangla-fort',
 'shree-shree-govindajee-temple',
 'tharon-cave',
 'senapati',
 'ukhrul',
 'tamenglong',
 'chandel',
 'churachandpur',
 'bishnupur',
 'thoubal',
 'shillong',
 'cherrapunji',
 'mawsynram',
 'jaintia-hills',
 'east-khasi-hills',
 'ri-bhoi',
 'west-garo-hills',
 'south-garo-hills',
 'north-garo-hills',
 'east-garo-hills',
 'west-jaintia-hills',
 'east-jaintia-hills',
 'nongpoh',
 'pynursla',
 'mairang',
 'nongstoin',
 'aizawl',
 'lunglei',
 'champhai',
 'kolasib',
 'lawngtlai',
 'saiha',
 'serchhip',
 'mamit',
 'khawzawl',
 'hnahthial',
 'saitual',
 'tawi',
 'reiek',
 'dampa-tiger-reserve',
 'murlen-national-park',
 'phawngpui-blue-mountain-national-park',
 'kohima',
 'dimapur',
 'mokokchung',
 'tuensang',
 'mon',
 'zunheboto',
 'wokha',
 'longleng',
 'kiphire',
 'phek',
 'noklak',
 'peren',
 'dzukou-valley',
 'intanki-national-park',
 'pulie-badze',
 'shirui-khul',
 'bhubaneswar',
 'puri',
 'konark',
 'cuttack',
 'rourkela',
 'sambalpur',
 'brahmapur',
 'puri-beach',
 'chilka-lake',
 'simlipal-national-park',
 'nandankanan-zoological-park',
 'dhauli-hills',
 'khandagiri-caves',
 'udayagiri-caves',
 'lalitgiri',
 'ratnagiri',
 'barabati-fort',
 'tikarpada-wildlife-sanctuary',
 'bhitarkanika-national-park',
 'gahirmatha-beach',
 'atri-hot-spring',
 'taratarini-temple',
 'maa-ugra-tara-temple',
 'bhitarakanika-mangrove-forest',
 'satkosia-gorge-wildlife-sanctuary',
 'debrigarh-wildlife-sanctuary',
 'kuldiha-wildlife-sanctuary',
 'hadgarh-wildlife-sanctuary',
 'narendrapur-wildlife-sanctuary',
 'chandipur-beach',
 'gopalpur-beach',
 'talsari-beach',
 'patanpur-beach',
 'balighai-beach',
 'ramachandi-beach',
 'daringbadi',
 'phulbani',
 'rayagada',
 'gunupur',
 'sonepur',
 'bolangir',
 'nuapada',
 'malkangiri',
 'koraput',
 'jeypore',
 'sunabeda',
 'damanjodi',
 'amritsar',
 'chandigarh',
 'ludhiana',
 'jalandhar',
 'patiala',
 'bathinda',
 'pathankot',
 'hoshiarpur',
 'ferozepur',
 'kapurthala',
 'moga',
 'muktsar',
 'barnala',
 'fazilka',
 'gurdaspur',
 'sangrur',
 'nawanshahr',
 'faridkot',
 'tarn-taran',
 'firozpur',
 'jaipur',
 'udaipur',
 'jodhpur',
 'jaisalmer',
 'ajmer',
 'pushkar',
 'bikaner',
 'mount-abu',
 'kota',
 'alwar',
 'bharatpur',
 'chittorgarh',
 'ranthambore-national-park',
 'sariska-tiger-reserve',
 'keoladeo-national-park',
 'desert-national-park',
 'sawai-madhopur',
 'dholpur',
 'tonk',
 'sikar',
 'jhunjhunu',
 'churu',
 'hanumangarh',
 'jalore',
 'gangtok',
 'yuksom',
 'ravangla',
 'pelling',
 'namchi',
 'mangan',
 'nathula-pass',
 'tsomgo-lake',
 'baba-harbhajan-singh-temple',
 'rumtek-monastery',
 'tashiding-monastery',
 'pemayangtse-monastery',
 'khecheopalri-lake',
 'menmecho-lake',
 'gurudongmar-lake',
 'tso-lhamo-lake',
 'chennai',
 'coimbatore',
 'madurai',
 'tiruchirappalli',
 'tirunelveli',
 'thanjavur',
 'kanyakumari',
 'rameswaram',
 'kodaikanal',
 'ooty',
 'coonoor',
 'yercaud',
 'yelagiri',
 'munnar',
 'mamallapuram',
 'pudukkottai',
 'sivaganga',
 'virudhunagar',
 'thoothukudi',
 'ranipet',
 'vellore',
 'cuddalore',
 'kanchipuram',
 'dharmapuri',
 'hyderabad',
 'warangal',
 'nizamabad',
 'karimnagar',
 'ramagundam',
 'khammam',
 'suryapet',
 'siddipet',
 'jagtial',
 'adilabad',
 'nalgonda',
 'mahbubnagar',
 'medak',
 'mancherial',
 'peddapalli',
 'kamareddy',
 'wanaparthy',
 'gadwal',
 'nagarkurnool',
 'jangaon',
 'bhongir',
 'sircilla',
 'mahabubabad',
 'kothagudem',
 'palamu',
 'mulugu',
 'vikarabad',
 'agartala',
 'udaipur',
 'dharmanagar',
 'kailashahar',
 'belonia',
 'sonamura',
 'unakoti',
 'sepa-hijala-wildlife-sanctuary',
 'tripura-sundari-temple',
 'bhuvaneswari-temple',
 'chabimura',
 'deotamura',
 'pilak',
 'neermahal',
 'rudrasagar-lake',
 'dumboor-lake',
 'agra',
 'varanasi',
 'lucknow',
 'kanpur',
 'allahabad',
 'ghaziabad',
 'noida',
 'meerut',
 'moradabad',
 'aligarh',
 'bareilly',
 'muzaffarnagar',
 'saharanpur',
 'gorakhpur',
 'jhansi',
 'mathura',
 'fatehpur-sikri',
 'ayodhya',
 'sarnath',
 'prayagraj',
 'budaun',
 'azamgarh',
 'mau',
 'ballia',
 'deoria',
 'gonda',
 'dehradun',
 'haridwar',
 'rishikesh',
 'mussoorie',
 'nainital',
 'almora',
 'pithoragarh',
 'chamoli',
 'rudraprayag',
 'uttarkashi',
 'bageshwar',
 'champawat',
 'pauri',
 'tehri',
 'new-tehri',
 'dhanaulti',
 'haldwani',
 'kashipur',
 'roorkie',
 'ramnagar',
 'kotdwar',
 'kolkata',
 'darjeeling',
 'howrah',
 'asansol',
 'siliguri',
 'durgapur',
 'bardhaman',
 'malda',
 'jalpaiguri',
 'nadia',
 'hooghly',
 'bankura',
 'purulia',
 'birbhum',
 'cooch-behar',
 'murshidabad',
 'west-midnapore',
 'east-midnapore',
 'south-24-parganas',
 'north-24-parganas',
 'jhargram',
 'port-blair',
 'havelock-island',
 'neil-island',
 'diglipur',
 'baratang',
 'rangat',
 'mayabunder',
 'wandoor',
 'mahatma-gandhi-marine-national-park',
 'campbell-bay-national-park',
 'galathea-national-park',
 'chandigarh',
 'sukhna-lake',
 'rock-garden',
 'rose-garden',
 'elante-mall',
 'leisure-valley',
 'silvassa',
 'diu',
 'daman',
 'vapi',
 'dadra',
 'khanvel',
 'moti-daman',
 'nani-daman',
 'new-delhi',
 'red-fort',
 'qutub-minar',
 'india-gate',
 'lotus-temple',
 'connaught-place',
 'chandni-chowk',
 'rashtrapati-bhavan',
 'srinagar',
 'gulmarg',
 'pahalgam',
 'sonmarg',
 'leh',
 'ladakh',
 'jammu',
 'katra',
 'patnitop',
 'rajouri',
 'udhampur',
 'anantnag',
 'baramulla',
 'kupwara',
 'pulwama',
 'bandipora',
 'ganderbal',
 'kulgam',
 'shopian',
 'samba',
 'kishtwar',
 'doda',
 'ramban',
 'reasi',
 'kargil',
 'leh',
 'nubra valley',
 'pangong lake',
 'kargil',
 'zanskar',
 'dras',
 'dha-hanu',
 'turtuk',
 'panamic hot springs',
 'magnetic hill',
 'hall of fame',
 'shanti stupa',
 'thiksey monastery',
 'hemis monastery',
 'alchi monastery'
]

# %%
len(cities)
# Out:
# 841

# %%
 response = requests.get('https://www.holidify.com/places/kashmir/packages.html')

# %%
response
# Out:
# <Response [200]>

# %%
html_content = response.text

# %%
html_content
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n\n\n\n\n\n\n\n\n<html>\n<head>\n\t\n\n\t\n\t\n\n\t\n\n\t\n\n\n\n<script>\n  dataLayer = [{\n    \'pageType\': \'Destination.Packages\',\n    \'placeCode\': \'KASHMIR\',\n    \'stateCode\' : \'JAMMU-AND-KASHMIR\',\n    \'countryCode\' : \'INDIA\',\n    \'monetized\' : \'2\',\n    \'category\' : \'Hills & Valleys.png\',\n    \'destinationTags\' : \'Hills & Valleys\',\n    \'packageMinRate\' : \'9999.0\',\n    \'hotelMinRate\' : \'0.0\',\n    \'siteVersion\' : \'4.85\'\n  }];\n</script>\n\n\t\n\n\n\n<title> 100 Kashmir Tour Packages (2024): Book Kashmir Holiday Packages at the Best Price </title>\n<link rel="apple-touch-icon" sizes="180x180" href="/res/images/apple-touch-icon.png">\n<link rel="icon" href="/res/images/favicon.png" type="image/x-icon" sizes="32x32">\n<link rel="manifest" href="/manifest.json">\n<link rel="canonical" href="/places/kashmir/packages.html">  \n<meta http-equiv="Content-Type" content="text/html;ch
# ...

# %%
soup = BeautifulSoup(html_content,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script>
#    dataLayer = [{
#     'pageType': 'Destination.Packages',
#     'placeCode': 'KASHMIR',
#     'stateCode' : 'JAMMU-AND-KASHMIR',
#     'countryCode' : 'INDIA',
#     'monetized' : '2',
#     'category' : 'Hills & Valleys.png',
#     'destinationTags' : 'Hills & Valleys',
#     'packageMinRate' : '9999.0',
#     'hotelMinRate' : '0.0',
#     'siteVersion' : '4.85'
#   }];
#   </script>
#   <title>
#    100 Kashmir Tour Packages (2024): Book Kashmir Holiday Packages at the Best Price
#   </title>
#   <link href="/res/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/res/images/favicon.png" rel="icon" sizes="32x32" type="image/x-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="/places/kashmir/packages.html" rel="canonical"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="utf-8" http-equiv="encoding"/>
# ...

# %%
package_name=[]


for i in soup.find_all("h3",class_="text-truncate"):
    
    name =i.text.strip()

    package_name.append(name)

# %%
package_name
# Out:
# ['4 Night 5 Days Kashmir Tour Package',
#  'Srinagar Gulmarg Package: Excursion to Pahalgam Valley',
#  'Kashmir Winter Special 2024 Package',
#  'Srinagar Package for 3 Nights - Shikara Ride on Dal Lake',
#  '5 Nights Kashmir Tour Package',
#  'Kashmir Honeymoon Package for 4 Nights 5 Days',
#  'Admirable Kashmir Tour Package',
#  'Picturesque Kashmir Tour Package',
#  'Srinagar Tour Packages 3 Nights 4 Days: Paradise on Earth Family Holiday',
#  'Kashmir with Mata Vaishno Devi 7 Night 8 Days Package',
#  'Kashmir Deluxe Package: 6 Nights 7 Days Tour',
#  'Kashmir Honeymoon Tour Package with Houseboat Stay',
#  'Kashmir Tulip Package 3 Nights 4 Days',
#  'Best Kashmir Tour Packages for Family with Houseboat Stay',
#  'Offbeat Kashmir Itinerary with Gurez Valley',
#  'Best of Kashmir Tour Package for 5 Nights/6 Days',
#  'Marvelous Kashmir Tour Package',
#  'Kashmir 8 Days Itinerary: Enthralling Trip with Srinagar Houseboat Stay',
#  'Kashmir Offbeat Tour Packages',
# ...

# %%
trip_duration=[]


for i in soup.find_all('p' , class_='trip-duration'):

    p= i.text.strip()

    trip_duration.append(p)

# %%
trip_duration
# Out:
# ['4 Nights / 5 Days',
#  '6 Nights / 7 Days',
#  '5 Nights / 6 Days',
#  '3 Nights / 4 Days',
#  '5 Nights / 6 Days',
#  '4 Nights / 5 Days',
#  '3 Nights / 4 Days',
#  '5 Nights / 6 Days',
#  '3 Nights / 4 Days',
#  '7 Nights / 8 Days',
#  '6 Nights / 7 Days',
#  '7 Nights / 8 Days',
#  '3 Nights / 4 Days',
#  '4 Nights / 5 Days',
#  '8 Nights / 9 Days',
#  '5 Nights / 6 Days',
#  '7 Nights / 8 Days',
#  '6 Nights / 7 Days',
#  '6 Nights / 7 Days',
#  '5 Nights / 6 Days',
#  '8 Nights / 9 Days',
#  '3 Nights / 4 Days',
#  '4 Nights / 5 Days',
#  '6 Nights / 7 Days',
#  '5 Nights / 6 Days',
#  '4 Nights / 5 Days',
#  '4 Nights / 5 Days',
#  '5 Nights / 6 Days',
#  '6 Nights / 7 Days',
#  '5 Nights / 6 Days',
#  '4 Nights / 5 Days',
#  '5 Nights / 6 Days',
#  '5 Nights / 6 Days',
#  '8 Nights / 9 Days',
#  '5 Nights / 6 Days',
#  '6 Nights / 7 Days',
#  '6 Nights / 7 Days',
#  '5 Nights / 6 Days',
#  '2 Nights / 3 Days',
#  '5 Nights / 6 Days',
#  '3 Nights / 4 Days',
# ...

# %%
city_list=[]


for i in soup.find_all('p' , class_='places-covered'):

    p= i.text.strip()

    city_list.append(p)

# %%
city_list
# Out:
# ['Srinagar(4N) →  Gulmarg(0N) →  Pahalgam(0N)',
#  'Srinagar(2N) → Pahalgam(2N) → Gulmarg(1N) →  Srinagar Houseboat(1N)',
#  'Srinagar(3N) →  Pahalgam(1N) →  Srinagar(1N)',
#  'Srinagar(3N) →  Gulmarg(0N) →  Pahalgam(0N)',
#  'Srinagar(4N) →  Pahalgam(1N)',
#  'Srinagar(4N)',
#  'Srinagar(2N) →  Srinagar(1N)',
#  'Srinagar Houseboat(1N) →  Gulmarg(1N) →  Pahalgam(1N) →  Srinagar(2N) →  Sonmarg(0N)',
#  'Srinagar(3N) →  Gulmarg(0N) →  Pahalgam(0N) →  Aru and Betaab Valley(0N)',
#  'Katra(2N) →  Srinagar(3N) →  Srinagar(1N) →  Pahalgam(1N)',
#  'Srinagar(4N) →  Pahalgam(1N) →  Srinagar(1N)',
#  'Srinagar Houseboat(2N) →  Gulmarg(2N) →  Pahalgam(1N) →  Srinagar(2N) →  Sonamarg(0N)',
#  'Srinagar(2N) →  Srinagar(1N)',
#  'Srinagar Houseboat(1N) →  Sonamarg(0N) →  Gulmarg(0N) →  Pahalgam(0N) →  Srinagar(3N)',
#  'Srinagar(2N) →  Gurez Valley(2N) →  Lolab Valley(3N) →  Srinagar(1N)',
#  'Srinagar(3N) →  Pahalgam(1N) →  Srinagar(1N)',
# ...

# %%
package_price=[]


for i in soup.find_all('p' , class_='price'):

    p= i.text.strip()

    package_price.append(p)

# %%
package_price
# Out:
# ['₹ 21,000*\n                \n                per adult',
#  '₹ 21,000*',
#  '₹ 35,498*\n                \n                per adult',
#  '₹ 35,498*',
#  '₹ 22,000*\n                \n                per adult',
#  '₹ 22,000*',
#  '₹ 19,600*\n                \n                per adult',
#  '₹ 19,600*',
#  '₹ 12,499*\n                \n                per adult',
#  '₹ 12,499*',
#  '₹ 11,000*\n                \n                per adult',
#  '₹ 11,000*',
#  '₹ 9,999*\n                \n                per adult',
#  '₹ 9,999*',
#  '₹ 12,800*\n                \n                per adult',
#  '₹ 12,800*',
#  '₹ 19,000*\n                \n                per adult',
#  '₹ 19,000*',
#  '₹ 52,000*\n                \n                per adult',
#  '₹ 52,000*',
#  '₹ 15,500*\n                \n                per adult',
#  '₹ 15,500*',
#  '₹ 39,999*\n                \n                per adult',
#  '₹ 39,999*',
#  '₹ 20,999*\n                \n                per adult',
#  '₹ 20,999*',
# ...

# %%
persons=[]


for i in soup.find_all('p' , class_='price-desc'):

    p= i.text.strip()

    persons.append(p)

# %%
persons
# Out:
# ['per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
#  'per adult on twin sharing',
# ...

# %%
new_package = soup.find_all('div',class_="row no-gutters inventory-card")

# %%
new_package
# Out:
# [<div class="row no-gutters inventory-card" dataid="12551" onclick="packageCardClick(12551, false, '');">
#  <div class="col-4 col-md-3">
#  <p class="label">Trending Now</p>
#  <img alt="" class="w-100 lazy" data-original="https://www.holidify.com/images/compressed/578.jpg?v=1.1" height="" src="/res/images/patt.png"/>
#  </div>
#  <div class="col-8 col-md-6 inventory-details">
#  <a href="https://www.holidify.com/package/beautiful-kashmir-4-nights-tour-package-12551.html?placeCode=kashmir" onclick="event.stopPropagation();" target="_blank">
#  <h3 class="name text-truncate"> 4 Night 5 Days Kashmir Tour Package </h3>
#  </a>
#  <p class="trip-duration">4 Nights / 5 Days</p>
#  <p class="places-covered" title="12551">Srinagar(4N) →  Gulmarg(0N) →  Pahalgam(0N)</p>
# ...

# %%
package_names = []
trip_durations = []
city_lists = []
package_prices = []
personss = []

# Loop through each package and extract details
for i in new_package:
    package_names.append(i.find("h3", class_="text-truncate").text.strip() if i.find("h3", class_="text-truncate") else None)
    
    trip_durationss = i.find('p', class_='trip-duration')
    trip_durations.append(trip_durationss.text.strip() if trip_durationss else None)
    
    city_lists.append(i.find('p', class_='places-covered').text.strip() if i.find('p', class_='places-covered') else None)
    
    package_prices.append(i.find('p', class_='price').text.strip() if i.find('p', class_='price') else None)
    
    personss.append(i.find('p', class_='price-desc').text.strip() if i.find('p', class_='price-desc') else None)

# Create DataFrame outside the loop
df = pd.DataFrame({
    'package_name': package_names,
    'duration': trip_durations,
    'city_list': city_lists,
    'price': package_prices,
    'persons': personss
})

# %%
df
# Out:
#                                          package_name           duration  \
# 0                 4 Night 5 Days Kashmir Tour Package  4 Nights / 5 Days
# 1   Srinagar Gulmarg Package: Excursion to Pahalga...  6 Nights / 7 Days
# 2                 Kashmir Winter Special 2024 Package  5 Nights / 6 Days
# 3   Srinagar Package for 3 Nights - Shikara Ride o...  3 Nights / 4 Days
# 4                       5 Nights Kashmir Tour Package  5 Nights / 6 Days
# 5       Kashmir Honeymoon Package for 4 Nights 5 Days  4 Nights / 5 Days
# 6                      Admirable Kashmir Tour Package  3 Nights / 4 Days
# 7                    Picturesque Kashmir Tour Package  5 Nights / 6 Days
# 8   Srinagar Tour Packages 3 Nights 4 Days: Paradi...  3 Nights / 4 Days
# 9   Kashmir with Mata Vaishno Devi 7 Night 8 Days ...  7 Nights / 8 Days
# 10       Kashmir Deluxe Package: 6 Nights 7 Days Tour  6 Nights / 7 Days
# 11  Kashmir Honeymoon Tour Package with Houseboat ...  7 Nights / 8 Days
# ...

# %%
import time
from requests.exceptions import ConnectionError

final_df_3 = pd.DataFrame()

for city in cities:
    url =  'https://www.holidify.com/places/{}/packages.html'.format(city)
    
    try:
        response = requests.get(url)
        response.raise_for_status() 
    except ConnectionError:
        print(f"Connection aborted for {city}, retrying in 5 seconds...")
        time.sleep(10)
        continue  
    except Exception as e:
        print(f"Error for {city}: {e}")
        continue
    
    html_contents = response.text
    soup = BeautifulSoup(html_contents, 'lxml')
    
    new_packages = soup.find_all('div', class_="row no-gutters inventory-card")

    package_names, trip_durations, city_lists, package_prices, personss = [], [], [], [], []
    
    for new_package in new_packages:
        package_names.append(new_package.find("h3", class_="text-truncate").text.strip() if new_package.find("h3", class_="text-truncate") else None)
        trip_durationss = new_package.find('p', class_='trip-duration')
        trip_durations.append(trip_durationss.text.strip() if trip_durationss else None)
        city_lists.append(new_package.find('p', class_='places-covered').text.strip() if new_package.find('p', class_='places-covered') else None)
        package_prices.append(new_package.find('p', class_='price').text.strip() if new_package.find('p', class_='price') else None)
        personss.append(new_package.find('p', class_='price-desc').text.strip() if new_package.find('p', class_='price-desc') else None)

    df = pd.DataFrame({
        'package_name': package_names,
        'duration': trip_durations,
        'city_list': city_lists,
        'price': package_prices,
        'persons': personss
    })
    
    final_df_3 = pd.concat([final_df_3, df], ignore_index=True)
# Out:
# Error for rajahmundry: 404 Client Error: 404 for url: https://www.holidify.com/places/rajahmundry/packages.html
# Error for horsley-hills: 404 Client Error: 404 for url: https://www.holidify.com/places/horsley-hills/packages.html
# Error for rollapadu-wildlife-sanctuary: 404 Client Error: 404 for url: https://www.holidify.com/places/rollapadu-wildlife-sanctuary/packages.html
# Error for lambasingi: 404 Client Error: 404 for url: https://www.holidify.com/places/lambasingi/packages.html
# Error for borra-caves: 404 Client Error: 404 for url: https://www.holidify.com/places/borra-caves/packages.html
# Error for bhavani-island: 404 Client Error: 404 for url: https://www.holidify.com/places/bhavani-island/packages.html
# Error for machilipatnam: 404 Client Error: 404 for url: https://www.holidify.com/places/machilipatnam/packages.html
# Error for yaganti: 404 Client Error: 404 for url: https://www.holidify.com/places/yaganti/packages.html
# ...

# %%
final_df_3
# Out:
#                                            package_name             duration  \
# 0                                    Amazing Amaravathi    2 Nights / 3 Days
# 1                    Alluring Amaravathi and Vijayawada    3 Nights / 4 Days
# 2              Awesome Amaravathi, Vijaywada & Kakinada    4 Nights / 5 Days
# 3       Delights of Andhra Pradesh including Amaravathi    6 Nights / 7 Days
# 4     Gems of Andhra Pradesh Including Amaravathi an...    7 Nights / 8 Days
# ...                                                 ...                  ...
# 3529  Ladakh & Kargil Honeymoon Package for Explorer...    8 Nights / 9 Days
# 3530                   Dazzling Srinagar, Kargil & More   9 Nights / 10 Days
# 3531            Incredible Ladakh, Manali, Nubra & More   9 Nights / 10 Days
# 3532             Srinagar Ladakh Adventure Tour Package    7 Nights / 8 Days
# 3533  Shimla to Jammu Ultimate Tour Package for 12 n...  12 Nights / 13 Days
#
# ...

# %%
final_df_3.duplicated().sum()
# Out:
# 1649

# %%
final_df_3.shape
# Out:
# (3534, 5)

# %%
final_df_3.to_csv('tour_packages.csv',index = False)
