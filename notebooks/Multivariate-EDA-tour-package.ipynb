# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HARSHIT JAIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv(r"C:\Users\HARSHIT JAIN\Desktop\data science projects\visit_and_tour_packages_project\datasets\feature-engineering-tour-package.csv")

# %%
df.head(10)
# Out:
#                                         package_name category_of_package  \
# 0                                 amazing amaravathi     holiday_package
# 1                 alluring amaravathi and vijayawada     holiday_package
# 2           awesome amaravathi, vijaywada & kakinada     holiday_package
# 3    delights of andhra pradesh including amaravathi     holiday_package
# 4  gems of andhra pradesh including amaravathi an...     offbeat_package
# 5              pilgrimage from bangalore to tirupati  spiritual packages
# 6                   chennai to tirupati tour package  spiritual packages
# 7              divine tirumala tirupati tour package  spiritual packages
# 8                 bangalore to tirupati tour package  spiritual packages
# 9                     tamil nadu temple tour package    cultural_package
#
#                                   cities_to_be_visit  count_of_cities  \
# 0                                         amaravathi                1
# ...

# %%
df.shape
# Out:
# (2494, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2494 entries, 0 to 2493
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   package_name                  2494 non-null   object
#  1   category_of_package           2494 non-null   object
#  2   cities_to_be_visit            2494 non-null   object
#  3   count_of_cities               2494 non-null   int64
#  4   categories_by_days            2494 non-null   object
#  5   no_of_nights                  2494 non-null   int64
#  6   no_of_days                    2494 non-null   int64
#  7   categories_by_price           2494 non-null   object
#  8   accommodation_facility        2494 non-null   object
#  9   price                         2494 non-null   float64
#  10  tokenized_cities_to_be_visit  2494 non-null   object
#  11  tokenized_package_name        2494 non-null   object
# dtypes: float64(1), int64(3), object(8)
# ...

# %%
df.drop(columns=['package_name','no_of_nights'],inplace=True)

# %%
df.head(10)
# Out:
#   category_of_package                                 cities_to_be_visit  \
# 0     holiday_package                                         amaravathi
# 1     holiday_package                            amaravathi ,  vijaywada
# 2     holiday_package                amaravathi ,  vijaywada ,  kakinada
# 3     holiday_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
# 4     offbeat_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
# 5  spiritual packages                             bangalore ,   tirupati
# 6  spiritual packages                              chennai  ,   tirupati
# 7  spiritual packages                              chennai  ,   tirupati
# 8  spiritual packages                              bangalore ,  tirupati
# 9    cultural_package  tiruchi ,   madurai ,   kanyakumari ,   ramesw...
#
#    count_of_cities categories_by_days  no_of_days categories_by_price  \
# 0                1         short trip           3              budget
# ...

# %% [markdown]
# # category_of_package vs price

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['category_of_package'],y=df['price'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='price'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['category_of_package'],y=df['price'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='price'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['category_of_package'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='no_of_days'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['category_of_package'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='no_of_days'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['category_of_package'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='count_of_cities'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['category_of_package'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='category_of_package', ylabel='count_of_cities'>

# %% [markdown]
# # categories_by_days

# %%
df.head()
# Out:
#   category_of_package                                 cities_to_be_visit  \
# 0     holiday_package                                         amaravathi
# 1     holiday_package                            amaravathi ,  vijaywada
# 2     holiday_package                amaravathi ,  vijaywada ,  kakinada
# 3     holiday_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
# 4     offbeat_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
#
#    count_of_cities categories_by_days  no_of_days categories_by_price  \
# 0                1         short trip           3              budget
# 1                2        medium trip           4              budget
# 2                3        medium trip           5              budget
# 3                6        medium trip           7            standard
# 4                7          long trip           8            standard
#
#   accommodation_facility    price  \
# 0     low-cost apartment   8000.0
# ...

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['categories_by_days'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='count_of_cities'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['categories_by_days'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='count_of_cities'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['categories_by_days'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='no_of_days'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['categories_by_days'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='no_of_days'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['categories_by_days'],y=df['price'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='price'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['categories_by_days'],y=df['price'])
# Out:
# <Axes: xlabel='categories_by_days', ylabel='price'>

# %% [markdown]
# # categories_by_price

# %%
df.head()
# Out:
#   category_of_package                                 cities_to_be_visit  \
# 0     holiday_package                                         amaravathi
# 1     holiday_package                            amaravathi ,  vijaywada
# 2     holiday_package                amaravathi ,  vijaywada ,  kakinada
# 3     holiday_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
# 4     offbeat_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
#
#    count_of_cities categories_by_days  no_of_days categories_by_price  \
# 0                1         short trip           3              budget
# 1                2        medium trip           4              budget
# 2                3        medium trip           5              budget
# 3                6        medium trip           7            standard
# 4                7          long trip           8            standard
#
#   accommodation_facility    price  \
# 0     low-cost apartment   8000.0
# ...

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['categories_by_price'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='categories_by_price', ylabel='count_of_cities'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['categories_by_price'],y=df['count_of_cities'])
# Out:
# <Axes: xlabel='categories_by_price', ylabel='count_of_cities'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['categories_by_price'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='categories_by_price', ylabel='no_of_days'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['categories_by_price'],y=df['no_of_days'])
# Out:
# <Axes: xlabel='categories_by_price', ylabel='no_of_days'>

# %% [markdown]
# # accommodation_facility

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=df['accommodation_facility'],y=df['price'])
# Out:
# <Axes: xlabel='accommodation_facility', ylabel='price'>

# %%
plt.figure(figsize=(25,15))
sns.boxplot(x=df['accommodation_facility'],y=df['price'])
# Out:
# <Axes: xlabel='accommodation_facility', ylabel='price'>

# %%
df.head()
# Out:
#   category_of_package                                 cities_to_be_visit  \
# 0     holiday_package                                         amaravathi
# 1     holiday_package                            amaravathi ,  vijaywada
# 2     holiday_package                amaravathi ,  vijaywada ,  kakinada
# 3     holiday_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
# 4     offbeat_package  tirupati ,  nellore ,  amaravathi ,  vijaywada...
#
#    count_of_cities categories_by_days  no_of_days categories_by_price  \
# 0                1         short trip           3              budget
# 1                2        medium trip           4              budget
# 2                3        medium trip           5              budget
# 3                6        medium trip           7            standard
# 4                7          long trip           8            standard
#
#   accommodation_facility    price  \
# 0     low-cost apartment   8000.0
# ...

# %%
sns.scatterplot(data=df,x='count_of_cities',y='price')
# Out:
# <Axes: xlabel='count_of_cities', ylabel='price'>

# %%
sns.scatterplot(data=df,x='no_of_days',y='price')
# Out:
# <Axes: xlabel='no_of_days', ylabel='price'>
