# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup 
import re
# Out:
# C:\Users\HARSHIT JAIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cities = [ 'araku-valley',
 'visakhapatnam',
 'amaravathi',
 'gandikota',
 'tirupati',
 'vijayawada',
 'anantapur',
 'srisailam',
 'ananthagiri-hills',
 'kurnool',
 'guntur',
 'nellore',
 'lepakshi',
 'rajahmundry',
 'horsley-hills',
 'rollapadu-wildlife-sanctuary',
 'lambasingi',
 'chittoor',
 'borra-caves',
 'bhavani-island',
 'machilipatnam',
 'kakinada',
 'konaseema',
 'srikalahasti',
 'mantralayam',
 'annavaram',
 'puttaparthi',
 'vizianagaram',
 'samalkot',
 'nagarjunakonda',
 'yaganti',
 'rushikonda-beach',
 'coringa-wildlife-sanctuary',
 'maredumilli',
 'draksharamam',
 'oravakallu-rock-garden',
 'ahobilam-temple',
 'rayadurg',
 'kaigal-falls',
 'tadipatri',
 'nagalapuram',
 'chirala-beach',
 'tawang',
 'ziro',
 'namdapha-national-park',
 'sela-pass',
 'bomdila',
 'roing',
 'itanagar',
 'tezu',
 'dirang',
 'pasighat',
 'aalo',
 'nuranang-falls',
 'tawang-monastery',
 'bhalukpong',
 'sangti-valley',
 'namsai',
 'bum-la-pass',
 'changlang',
 'damro',
 'madhuri-lake',
 'anini',
 'mechuka',
 'daporijo',
 'pakhui-wildlife-sanctuary',
 'gorichen-peak',
 'golden-pagoda',
 'tirap',
 'khonsa',
 'yingkiong',
 'anjaw',
 'yupia',
 'kaziranga-national-park',
 'majuli',
 'guwahati',
 'manas-national-park',
 'dibrugarh',
 'jorhat',
 'hajo',
 'bogamati',
 'mayong',
 'dibru-saikhowa-national-park',
 'pobitora-wildlife-sanctuary',
 'barpeta',
 'umananda-island',
 'nameri-national-park',
 'tinsukia',
 'sivasagar',
 'diphu',
 'silchar',
 'goalpara',
 'dispur',
 'sualkuchi',
 'orang-national-park',
 'lilabari',
 'karimganj',
 'bongaigaon',
 'hailakandi',
 'dhemaji',
 'nalbari',
 'darrang',
 'morigaon',
 'nagaon',
 'sadiya',
 'digboi',
 'haflong',
 'tezpur',
 'bodh-gaya',
 'patna',
 'nalanda',
 'vaishali',
 'rajgir',
 'madhubani',
 'sitamarhi',
 'valmiki-national-park',
 'bhagalpur',
 'pawapuri',
 'hajipur',
 'muzaffarpur',
 'lauriya-nandangarh',
 'chhat-puja',
 'tomb-of-sher-shah-suri',
 'navlakha-palace',
 'jal-mandir',
 'mundeshwari-temple',
 'barnawapara-wildlife-sanctuary',
 'raipur',
 'jagdalpur',
 'charre-marre-waterfalls',
 'sirpur',
 'mainpat',
 'madku-dweep',
 'dhamtari',
 'bhilai',
 'chitrakote-falls',
 'indravati-national-park',
 'chirmiri',
 'tirathgarh-falls',
 'dantewada',
 'ghatarani-waterfalls',
 'bhoramdeo-temple',
 'malhar',
 'rajim',
 'guru-ghasidas-sanjay-national-park',
 'kanger-ghati-national-park',
 'purkhauti-muktangan',
 'achanakmar-wildlife-sanctuary',
 'calangute-beach',
 'fort-aguada',
 'cruise-in-goa',
 'water-sports-in-goa',
 'dudhsagar-falls',
 'anjuna-beach',
 'chapora-fort',
 'baga-beach',
 'palolem-beach',
 'varca-beach',
 'colva-beach',
 'benaulim-beach',
 'candolim-beach',
 'miramar-beach',
 'donapaula-bay',
 'agonda-beach',
 'butterfly-beach',
 'st-francis-church',
 'se-cathedral',
 'goa-state-museum',
 'sri-mangeshi-temple',
 'udaygiri',
 'sinquerim-fort',
 'corjuem-fort',
 'cab-de-rama-fort',
 'trevor’s-bar',
 'goa-veterinary-hospital',
 'dwarka',
 'somnath',
 'gir-national-park',
 'diu',
 'surat',
 'vadodara',
 'ahmedabad',
 'junagadh',
 'rajkot',
 'gandhinagar',
 'jamnagar',
 'bhavnagar',
 'porbandar',
 'kutch',
 'saputara',
 'daman',
 'silvassa',
 'champaner',
 'dholavira',
 'modhera',
 'faridabad',
 'gurgaon',
 'hisar',
 'rohtak',
 'panipat',
 'karnal',
 'ambala',
 'pinjore',
 'kurukshetra',
 'yamunanagar',
 'sonipat',
 'jind',
 'bhiwani',
 'bahadurgarh',
 'jhajjar',
 'manali',
 'shimla',
 'kasol',
 'mcleodganj',
 'dharamshala',
 'spiti-valley',
 'kasauli',
 'dalhousie',
 'kullu',
 'bir-billing',
 'chail',
 'khajjiar',
 'kufri',
 'parvati-valley',
 'tirthan-valley',
 'jibhi',
 'sethan-valley',
 'kaza',
 'triund',
 'malana',
 'tosh',
 'palampur',
 'narkanda',
 'prashar-lake-trek',
 'sissu',
 'naggar',
 'sarahan',
 'jispa',
 'kalpa',
 'fagu',
 'kinnaur',
 'kangra',
 'keylong',
 'rohtang-pass',
 'shoghi',
 'chamba',
 'tattapani',
 'mandi',
 'manikaran-sahib',
 'indravati-pass-trek',
 'nahan',
 'shoja',
 'deoghar',
 'jamshedpur',
 'ranchi',
 'betla-national-park',
 'ghatshila',
 'shikharji',
 'dasham-falls',
 'netarhat',
 'massanjore-dam',
 'hazaribagh',
 'bokaro-steel-city',
 'dhanbad',
 'parasnath-hills',
 'rajrappa',
 'jubilee-park',
 'hundru-falls',
 'jonha-falls',
 'dassam-falls',
 'usri-falls',
 'palkot-wildlife-sanctuary',
 'chandil-dam',
 'dimna-lake',
 'getalsud-dam',
 'topchanchi-lake',
 'khandoli-dam',
 'maithon-dam',
 'tagore-hill',
 'naulakha-temple',
 'sun-temple',
 'jagannath-temple',
 'ranchi-lake',
 'birsa-munda-zoological-park',
 'deori-temple',
 'rock-garden',
 'baidyanath-dham',
 'basukinath',
 'lodh-falls',
 'saranda-forest',
 'chota-nagpur-plateau',
 'coorg',
 'badami',
 'mysore',
 'hampi',
 'gokarna',
 'udupi',
 'chikmagalur',
 'jog-falls',
 'murudeshwar',
 'bangalore',
 'dandeli',
 'bandipur-national-park',
 'nagarhole-national-park',
 'kabini',
 'kemmanagundi',
 'thirthahalli',
 'kudremukh',
 'shravanabelagola',
 'pattadakal',
 'shimoga-shivamogga',
 'devbagh',
 'nandi-hills',
 'karwar',
 'halebidu',
 'bijapur',
 'shivagange',
 'maravanthe',
 'mangalore',
 'srirangapatna',
 'savandurga',
 'chikkaballapur',
 'honnemaradu',
 'anthargange',
 'bheemeshwari',
 'dubare',
 'dharmasthala',
 'kundapura',
 'br-hills',
 'sringeri',
 'shivanasamudra-falls',
 'aihole',
 'bidar',
 'belgaum',
 'gokak-falls',
 'patgaon',
 'munnar',
 'kochi',
 'alleppey',
 'wayanad',
 'varkala',
 'kumarakom',
 'kumbalangi',
 'vagamon',
 'kovalam',
 'periyar-national-park',
 'idukki',
 'kozhikode',
 'poovar',
 'sabarimala',
 'vythiri',
 'thekkady',
 'bekal',
 'thrissur',
 'palakkad',
 'thalassery',
 'nelliyampathy',
 'nilambur',
 'ponmudi',
 'trivandrum',
 'kalpetta',
 'kollam',
 'peerumedu',
 'guruvayur',
 'malampuzha',
 'kannur',
 'kasaragod',
 'thenmala',
 'kottayam',
 'silent-valley-national-park',
 'kumily',
 'ponnani',
 'pathanamthitta',
 'ernakulam',
 'thattekad-bird-sanctuary',
 'muthanga-wildlife-sanctuary',
 'malappuram',
 'devikulam',
 'bhopal',
 'indore',
 'ujjain',
 'gwalior',
 'jabalpur',
 'sanchi',
 'khajuraho',
 'kanha-national-park',
 'bandhavgarh-national-park',
 'pench-national-park',
 'satpura-national-park',
 'amarkantak',
 'dhuandhar-falls',
 'bhimbetka',
 'maheshwar',
 'mandu',
 'omkareshwar',
 'pachmarhi',
 'tawa-dam',
 'udaygiri',
 'sagar',
 'chanderi',
 'orchha',
 'shivpuri',
 'guna',
 'neemuch',
 'mandsaur',
 'ratlam',
 'vidisha',
 'rewa',
 'satna',
 'sidhi',
 'singrauli',
 'shajapur',
 'sheopur',
 'shivni',
 'sehore',
 'seoni',
 'harda',
 'hoshangabad',
 'dhar',
 'dindori',
 'damoh',
 'chhindwara',
 'betul',
 'burhanpur',
 'ashoknagar',
 'anuppur',
 'alirajpur',
 'khandwa',
 'khargone',
 'katni',
 'jhabua',
 'shyopur',
 'narsinghpur',
 'neemuch',
 'mumbai',
 'pune',
 'nashik',
 'aurangabad',
 'nagpur',
 'mahabaleshwar',
 'lonavala',
 'khandala',
 'matheran',
 'ajanta-caves',
 'ellora-caves',
 'elephanta-caves',
 'tadoba-national-park',
 'pench-national-park',
 'sinhagad-fort',
 'raigad-fort',
 'shirdi',
 'shani-shingnapur',
 'trimbakeshwar',
 'grishneshwar',
 'aundha-nagnath',
 'parli-vaijnath',
 'vajreshwari',
 'malshej-ghat',
 'bhimashankar',
 'saputara',
 'toranmal',
 'chikhaldara',
 'panvel',
 'alibaug',
 'murud-janjira',
 'dapoli',
 'imphal',
 'loktak-lake',
 'kangla-fort',
 'shree-shree-govindajee-temple',
 'tharon-cave',
 'senapati',
 'ukhrul',
 'tamenglong',
 'chandel',
 'churachandpur',
 'bishnupur',
 'thoubal',
 'shillong',
 'cherrapunji',
 'mawsynram',
 'jaintia-hills',
 'east-khasi-hills',
 'ri-bhoi',
 'west-garo-hills',
 'south-garo-hills',
 'north-garo-hills',
 'east-garo-hills',
 'west-jaintia-hills',
 'east-jaintia-hills',
 'nongpoh',
 'pynursla',
 'mairang',
 'nongstoin',
 'aizawl',
 'lunglei',
 'champhai',
 'kolasib',
 'lawngtlai',
 'saiha',
 'serchhip',
 'mamit',
 'khawzawl',
 'hnahthial',
 'saitual',
 'tawi',
 'reiek',
 'dampa-tiger-reserve',
 'murlen-national-park',
 'phawngpui-blue-mountain-national-park',
 'kohima',
 'dimapur',
 'mokokchung',
 'tuensang',
 'mon',
 'zunheboto',
 'wokha',
 'longleng',
 'kiphire',
 'phek',
 'noklak',
 'peren',
 'dzukou-valley',
 'intanki-national-park',
 'pulie-badze',
 'shirui-khul',
 'bhubaneswar',
 'puri',
 'konark',
 'cuttack',
 'rourkela',
 'sambalpur',
 'brahmapur',
 'puri-beach',
 'chilka-lake',
 'simlipal-national-park',
 'nandankanan-zoological-park',
 'dhauli-hills',
 'khandagiri-caves',
 'udayagiri-caves',
 'lalitgiri',
 'ratnagiri',
 'barabati-fort',
 'tikarpada-wildlife-sanctuary',
 'bhitarkanika-national-park',
 'gahirmatha-beach',
 'atri-hot-spring',
 'taratarini-temple',
 'maa-ugra-tara-temple',
 'bhitarakanika-mangrove-forest',
 'satkosia-gorge-wildlife-sanctuary',
 'debrigarh-wildlife-sanctuary',
 'kuldiha-wildlife-sanctuary',
 'hadgarh-wildlife-sanctuary',
 'narendrapur-wildlife-sanctuary',
 'chandipur-beach',
 'gopalpur-beach',
 'talsari-beach',
 'patanpur-beach',
 'balighai-beach',
 'ramachandi-beach',
 'daringbadi',
 'phulbani',
 'rayagada',
 'gunupur',
 'sonepur',
 'bolangir',
 'nuapada',
 'malkangiri',
 'koraput',
 'jeypore',
 'sunabeda',
 'damanjodi',
 'amritsar',
 'chandigarh',
 'ludhiana',
 'jalandhar',
 'patiala',
 'bathinda',
 'pathankot',
 'hoshiarpur',
 'ferozepur',
 'kapurthala',
 'moga',
 'muktsar',
 'barnala',
 'fazilka',
 'gurdaspur',
 'sangrur',
 'nawanshahr',
 'faridkot',
 'tarn-taran',
 'firozpur',
 'jaipur',
 'udaipur',
 'jodhpur',
 'jaisalmer',
 'ajmer',
 'pushkar',
 'bikaner',
 'mount-abu',
 'kota',
 'alwar',
 'bharatpur',
 'chittorgarh',
 'ranthambore-national-park',
 'sariska-tiger-reserve',
 'keoladeo-national-park',
 'desert-national-park',
 'sawai-madhopur',
 'dholpur',
 'tonk',
 'sikar',
 'jhunjhunu',
 'churu',
 'hanumangarh',
 'jalore',
 'gangtok',
 'yuksom',
 'ravangla',
 'pelling',
 'namchi',
 'mangan',
 'nathula-pass',
 'tsomgo-lake',
 'baba-harbhajan-singh-temple',
 'rumtek-monastery',
 'tashiding-monastery',
 'pemayangtse-monastery',
 'khecheopalri-lake',
 'menmecho-lake',
 'gurudongmar-lake',
 'tso-lhamo-lake',
 'chennai',
 'coimbatore',
 'madurai',
 'tiruchirappalli',
 'tirunelveli',
 'thanjavur',
 'kanyakumari',
 'rameswaram',
 'kodaikanal',
 'ooty',
 'coonoor',
 'yercaud',
 'yelagiri',
 'munnar',
 'mamallapuram',
 'pudukkottai',
 'sivaganga',
 'virudhunagar',
 'thoothukudi',
 'ranipet',
 'vellore',
 'cuddalore',
 'kanchipuram',
 'dharmapuri',
 'hyderabad',
 'warangal',
 'nizamabad',
 'karimnagar',
 'ramagundam',
 'khammam',
 'suryapet',
 'siddipet',
 'jagtial',
 'adilabad',
 'nalgonda',
 'mahbubnagar',
 'medak',
 'mancherial',
 'peddapalli',
 'kamareddy',
 'wanaparthy',
 'gadwal',
 'nagarkurnool',
 'jangaon',
 'bhongir',
 'sircilla',
 'mahabubabad',
 'kothagudem',
 'palamu',
 'mulugu',
 'vikarabad',
 'agartala',
 'udaipur',
 'dharmanagar',
 'kailashahar',
 'belonia',
 'sonamura',
 'unakoti',
 'sepa-hijala-wildlife-sanctuary',
 'tripura-sundari-temple',
 'bhuvaneswari-temple',
 'chabimura',
 'deotamura',
 'pilak',
 'neermahal',
 'rudrasagar-lake',
 'dumboor-lake',
 'agra',
 'varanasi',
 'lucknow',
 'kanpur',
 'allahabad',
 'ghaziabad',
 'noida',
 'meerut',
 'moradabad',
 'aligarh',
 'bareilly',
 'muzaffarnagar',
 'saharanpur',
 'gorakhpur',
 'jhansi',
 'mathura',
 'fatehpur-sikri',
 'ayodhya',
 'sarnath',
 'prayagraj',
 'budaun',
 'azamgarh',
 'mau',
 'ballia',
 'deoria',
 'gonda',
 'dehradun',
 'haridwar',
 'rishikesh',
 'mussoorie',
 'nainital',
 'almora',
 'pithoragarh',
 'chamoli',
 'rudraprayag',
 'uttarkashi',
 'bageshwar',
 'champawat',
 'pauri',
 'tehri',
 'new-tehri',
 'dhanaulti',
 'haldwani',
 'kashipur',
 'roorkie',
 'ramnagar',
 'kotdwar',
 'kolkata',
 'darjeeling',
 'howrah',
 'asansol',
 'siliguri',
 'durgapur',
 'bardhaman',
 'malda',
 'jalpaiguri',
 'nadia',
 'hooghly',
 'bankura',
 'purulia',
 'birbhum',
 'cooch-behar',
 'murshidabad',
 'west-midnapore',
 'east-midnapore',
 'south-24-parganas',
 'north-24-parganas',
 'jhargram',
 'port-blair',
 'havelock-island',
 'neil-island',
 'diglipur',
 'baratang',
 'rangat',
 'mayabunder',
 'wandoor',
 'mahatma-gandhi-marine-national-park',
 'campbell-bay-national-park',
 'galathea-national-park',
 'chandigarh',
 'sukhna-lake',
 'rock-garden',
 'rose-garden',
 'elante-mall',
 'leisure-valley',
 'silvassa',
 'diu',
 'daman',
 'vapi',
 'dadra',
 'khanvel',
 'moti-daman',
 'nani-daman',
 'new-delhi',
 'red-fort',
 'qutub-minar',
 'india-gate',
 'lotus-temple',
 'connaught-place',
 'chandni-chowk',
 'rashtrapati-bhavan',
 'srinagar',
 'gulmarg',
 'pahalgam',
 'sonmarg',
 'leh',
 'ladakh',
 'jammu',
 'katra',
 'patnitop',
 'rajouri',
 'udhampur',
 'anantnag',
 'baramulla',
 'kupwara',
 'pulwama',
 'bandipora',
 'ganderbal',
 'kulgam',
 'shopian',
 'samba',
 'kishtwar',
 'doda',
 'ramban',
 'reasi',
 'kargil',
 'leh',
 'nubra valley',
 'pangong lake',
 'kargil',
 'zanskar',
 'dras',
 'dha-hanu',
 'turtuk',
 'panamic hot springs',
 'magnetic hill',
 'hall of fame',
 'shanti stupa',
 'thiksey monastery',
 'hemis monastery',
 'alchi monastery'
]

# %%
final_df = pd.DataFrame()


for city in cities:
    
    url = 'https://www.holidify.com/places/{}/sightseeing-and-things-to-do.html'.format(city)
    
    
    response = requests.get(url)
    html_contents = response.text
    
    
    soup = BeautifulSoup(html_contents, 'lxml')
    
    
    packages = soup.find_all('div', class_="col-12 col-md-6 pr-md-3")
    
    
    visit_places = []
    rating = []
    places = []
    all_about = []
    
    
    for package in packages:
        visit_places.append(package.find('h3').text.strip() if package.find('h3') else None)

        rating_element = package.find('span', class_='rating-badge')
        rating.append(rating_element.text.strip() if rating_element else None)

        places.append(package.find('p', class_='objective').text.strip() if package.find('p', class_='objective') else None)

        all_about.append(package.find('p', class_='card-text').text.strip() if package.find('p', class_='card-text') else None)
    
    
    df = pd.DataFrame({
        'visit_places': visit_places,
        'rating': rating,
        'city_names':places,  
        'visit_place_summary': all_about
    })
    

    final_df = pd.concat([final_df, df], ignore_index=True)

# %%
final_df
# Out:
#                 visit_places    rating  \
# 0             1. Borra Caves  4.6\n /5
# 1       2. Katiki Waterfalls  4.1\n /5
# 2     3. Chaparai Waterfalls  3.9\n /5
# 3     4. Tadimada Waterfalls      None
# 4            5. Matsyagundam      None
# ...                      ...       ...
# 6285             2. Minamarg      None
# 6286              3. Matayen      None
# 6287       4. Ningoor Masjid      None
# 6288   5. Mushko Valley Trek      None
# 6289    6. Trek to Saliskote      None
#
#                                              city_names  \
# 0     18 km  from city center \n \n 1 out of 8 Place...
# 1     14 km  from city center \n \n 2 out of 8 Place...
# 2            3 out of 8 Places To Visit in Araku Valley
# 3            4 out of 8 Places To Visit in Araku Valley
# 4     32 km  from city center \n \n 5 out of 8 Place...
# ...                                                 ...
# 6285                                               None
# 6286                                               None
# 6287                                               None
# 6288                                               None
# 6289                                               None
#
#                                     visit_place_summary
# 0     The Borra Caves or Borra Guhalu, as is known i...
# 1     With the clear waters of river Gosthani, this ...
# 2     At a distance of just 13 km from Araku, the Ch...
# 3     The Tadimada Waterfalls is a beauty that would...
# 4     Popularly known as the fish pool, Matsyagundam...
# ...                                                 ...
# 6285
# 6286
# 6287
# 6288
# 6289
#
# [6290 rows x 4 columns]

# %%
final_df.shape
# Out:
# (6290, 4)

# %%
final_df.duplicated().sum()
# Out:
# 233

# %%
final_df.to_csv('city_visiting_places.csv',index = False)
