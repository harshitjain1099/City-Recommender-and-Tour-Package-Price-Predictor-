# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HARSHIT JAIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv(r"C:\Users\HARSHIT JAIN\Desktop\data science projects\visit_and_tour_packages_project\datasets\feature-engineering-city-state.csv")

# %%
df.head()
# Out:
#        visiting_places  visiting_places_rating  distance_from_city_center  \
# 0          borra caves                     4.6                       18.0
# 1    katiki waterfalls                     4.1                       14.0
# 2  chaparai waterfalls                     3.9                        NaN
# 3  tadimada waterfalls                     NaN                        NaN
# 4         matsyagundam                     NaN                       32.0
#
#     cities_name  city_rating   city_type   city_visit_time  \
# 0  araku valley          4.8  hilly type  autumn_to_winter
# 1  araku valley          4.8  hilly type  autumn_to_winter
# 2  araku valley          4.8  hilly type  autumn_to_winter
# 3  araku valley          4.8  hilly type  autumn_to_winter
# 4  araku valley          4.8  hilly type  autumn_to_winter
#
#    no_of_tourist_attration     states_name  \
# 0                      8.0  andhra pradesh
# 1                      8.0  andhra pradesh
# ...

# %%
df.isnull().sum()
# Out:
# visiting_places                        0
# visiting_places_rating              2631
# distance_from_city_center            824
# cities_name                          381
# city_rating                          657
# city_type                            381
# city_visit_time                      657
# no_of_tourist_attration              657
# states_name                          555
# state_categories                     555
# state_visit_time                     734
# visiting_place_summary               306
# visiting_place_tokenized_summary     306
# city_summary                         555
# city_tokenized_summary               555
# best_time_to_visit                   657
# dtype: int64

# %% [markdown]
# # visiting_places

# %%
df['visiting_places'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # visiting_places_rating

# %%
df['visiting_places_rating'].isnull().sum()
# Out:
# 2631

# %%
df['visiting_places_rating'].value_counts()
# Out:
# visiting_places_rating
# 3.1    645
# 3.2    418
# 3.0    338
# 3.5    302
# 4.2    271
# 4.3    197
# 3.4    193
# 4.1    165
# 3.6    156
# 3.3    154
# 4.0    118
# 3.7    114
# 4.5     96
# 4.4     75
# 3.8     70
# 3.9     65
# 4.6     53
# 4.7     33
# 4.9     10
# 4.8     10
# 2.9      2
# 2.8      1
# Name: count, dtype: int64

# %%
df['visiting_places_rating'].describe()
# Out:
# count    3486.000000
# mean        3.578801
# std         0.504915
# min         2.800000
# 25%         3.100000
# 50%         3.400000
# 75%         4.100000
# max         4.900000
# Name: visiting_places_rating, dtype: float64

# %%
df['visiting_places_rating'] = df['visiting_places_rating'].fillna(value=3.57)

# %%
df['visiting_places_rating'].value_counts()
# Out:
# visiting_places_rating
# 3.57    2631
# 3.10     645
# 3.20     418
# 3.00     338
# 3.50     302
# 4.20     271
# 4.30     197
# 3.40     193
# 4.10     165
# 3.60     156
# 3.30     154
# 4.00     118
# 3.70     114
# 4.50      96
# 4.40      75
# 3.80      70
# 3.90      65
# 4.60      53
# 4.70      33
# 4.90      10
# 4.80      10
# 2.90       2
# 2.80       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        visiting_places  visiting_places_rating  distance_from_city_center  \
# 0          borra caves                    4.60                       18.0
# 1    katiki waterfalls                    4.10                       14.0
# 2  chaparai waterfalls                    3.90                        NaN
# 3  tadimada waterfalls                    3.57                        NaN
# 4         matsyagundam                    3.57                       32.0
#
#     cities_name  city_rating   city_type   city_visit_time  \
# 0  araku valley          4.8  hilly type  autumn_to_winter
# 1  araku valley          4.8  hilly type  autumn_to_winter
# 2  araku valley          4.8  hilly type  autumn_to_winter
# 3  araku valley          4.8  hilly type  autumn_to_winter
# 4  araku valley          4.8  hilly type  autumn_to_winter
#
#    no_of_tourist_attration     states_name  \
# 0                      8.0  andhra pradesh
# 1                      8.0  andhra pradesh
# ...

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           824
# cities_name                         381
# city_rating                         657
# city_type                           381
# city_visit_time                     657
# no_of_tourist_attration             657
# states_name                         555
# state_categories                    555
# state_visit_time                    734
# visiting_place_summary              306
# visiting_place_tokenized_summary    306
# city_summary                        555
# city_tokenized_summary              555
# best_time_to_visit                  657
# dtype: int64

# %% [markdown]
# # cities_name

# %%
df['cities_name'].isnull().sum()
# Out:
# 381

# %%
df = df[df['cities_name'].notnull()]

# %%
df.head()
# Out:
#        visiting_places  visiting_places_rating  distance_from_city_center  \
# 0          borra caves                    4.60                       18.0
# 1    katiki waterfalls                    4.10                       14.0
# 2  chaparai waterfalls                    3.90                        NaN
# 3  tadimada waterfalls                    3.57                        NaN
# 4         matsyagundam                    3.57                       32.0
#
#     cities_name  city_rating   city_type   city_visit_time  \
# 0  araku valley          4.8  hilly type  autumn_to_winter
# 1  araku valley          4.8  hilly type  autumn_to_winter
# 2  araku valley          4.8  hilly type  autumn_to_winter
# 3  araku valley          4.8  hilly type  autumn_to_winter
# 4  araku valley          4.8  hilly type  autumn_to_winter
#
#    no_of_tourist_attration     states_name  \
# 0                      8.0  andhra pradesh
# 1                      8.0  andhra pradesh
# ...

# %%
df.shape
# Out:
# (5736, 16)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                         276
# city_type                             0
# city_visit_time                     276
# no_of_tourist_attration             276
# states_name                         174
# state_categories                    174
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %% [markdown]
# # city_rating

# %%
df['city_rating'].describe()
# Out:
# count    5460.000000
# mean        4.154817
# std         0.429730
# min         1.000000
# 25%         4.000000
# 50%         4.200000
# 75%         4.400000
# max         5.000000
# Name: city_rating, dtype: float64

# %%
df['city_rating'] = df['city_rating'].fillna(value= 4.1)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                     276
# no_of_tourist_attration             276
# states_name                         174
# state_categories                    174
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %% [markdown]
# # no_of_tourist_attration

# %%
df['no_of_tourist_attration'].isnull().sum()
# Out:
# 276

# %%
df[df['no_of_tourist_attration'].isnull()].head()
# Out:
#                visiting_places  visiting_places_rating  \
# 775                naida caves                     3.5
# 776                nagoa beach                     4.2
# 777  gangeshwar mahadev temple                     3.2
# 778                   diu fort                     4.2
# 779              ghoghla beach                     3.6
#
#      distance_from_city_center cities_name  city_rating   city_type  \
# 775                        1.0         diu          4.1  beach type
# 776                        5.0         diu          4.1  beach type
# 777                        4.0         diu          4.1  beach type
# 778                        1.0         diu          4.1  beach type
# 779                        3.0         diu          4.1  beach type
#
#     city_visit_time  no_of_tourist_attration states_name state_categories  \
# 775             NaN                      NaN         NaN              NaN
# ...

# %%
tourist_attractions = {
    'diu': 20,
    'daman': 18,
    'silvassa': 10,
    'belgaum': 12,
    'chandigarh': 51,
    'chamoli' : 13,
    'haldwani' : 3,
    'port blair': 22,
    'neil island': 6,
    'leh': 10,
    'ladakh': 52,
    'kargil' :8
}

# %%
 df['no_of_tourist_attration'] =df.apply(
    lambda row: tourist_attractions.get(row['cities_name'], row['no_of_tourist_attration']),
    axis=1
)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                     276
# no_of_tourist_attration               0
# states_name                         174
# state_categories                    174
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %%
df[df['no_of_tourist_attration'].isnull()]
# Out:
# Empty DataFrame
# Columns: [visiting_places, visiting_places_rating, distance_from_city_center, cities_name, city_rating, city_type, city_visit_time, no_of_tourist_attration, states_name, state_categories, state_visit_time, visiting_place_summary, visiting_place_tokenized_summary, city_summary, city_tokenized_summary, best_time_to_visit]
# Index: []

# %% [markdown]
# # city_visit_time

# %%
df['city_visit_time'].value_counts()
# Out:
# city_visit_time
# autumn_to_winter       2850
# throughout_the_year    1501
# autumn_to_summer        777
# summer_to_autumn        285
# summer_to_winter         47
# Name: count, dtype: int64

# %%
df['city_visit_time'].isnull().sum()
# Out:
# 276

# %%
df[df['city_visit_time'].isnull()].head()
# Out:
#                visiting_places  visiting_places_rating  \
# 775                naida caves                     3.5
# 776                nagoa beach                     4.2
# 777  gangeshwar mahadev temple                     3.2
# 778                   diu fort                     4.2
# 779              ghoghla beach                     3.6
#
#      distance_from_city_center cities_name  city_rating   city_type  \
# 775                        1.0         diu          4.1  beach type
# 776                        5.0         diu          4.1  beach type
# 777                        4.0         diu          4.1  beach type
# 778                        1.0         diu          4.1  beach type
# 779                        3.0         diu          4.1  beach type
#
#     city_visit_time  no_of_tourist_attration states_name state_categories  \
# 775             NaN                     20.0         NaN              NaN
# ...

# %%
visit_time = {
    'diu':'autumn_to_winter',
    'daman': 'autumn_to_winter',
    'silvassa': 'autumn_to_winter',
    'belgaum': 'summer_to_autumn',
    'chandigarh':'autumn_to_winter',
    'chamoli' : 'autumn_to_summer',
    'haldwani' :'autumn_to_winter' ,
    'port blair': 'autumn_to_summer',
    'neil island': 'autumn_to_summer',
    'leh': 'summer_to_autumn',
    'ladakh': 'summer_to_autumn',
    'kargil' :'summer_to_autumn'
}

# %%
 df['city_visit_time'] =df.apply(
    lambda row: visit_time.get(row['cities_name'], row['city_visit_time']),
    axis=1
)

# %%
df[df['city_visit_time'].isnull()]
# Out:
# Empty DataFrame
# Columns: [visiting_places, visiting_places_rating, distance_from_city_center, cities_name, city_rating, city_type, city_visit_time, no_of_tourist_attration, states_name, state_categories, state_visit_time, visiting_place_summary, visiting_place_tokenized_summary, city_summary, city_tokenized_summary, best_time_to_visit]
# Index: []

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                       0
# no_of_tourist_attration               0
# states_name                         174
# state_categories                    174
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %%
df.head()
# Out:
#        visiting_places  visiting_places_rating  distance_from_city_center  \
# 0          borra caves                    4.60                       18.0
# 1    katiki waterfalls                    4.10                       14.0
# 2  chaparai waterfalls                    3.90                        NaN
# 3  tadimada waterfalls                    3.57                        NaN
# 4         matsyagundam                    3.57                       32.0
#
#     cities_name  city_rating   city_type   city_visit_time  \
# 0  araku valley          4.8  hilly type  autumn_to_winter
# 1  araku valley          4.8  hilly type  autumn_to_winter
# 2  araku valley          4.8  hilly type  autumn_to_winter
# 3  araku valley          4.8  hilly type  autumn_to_winter
# 4  araku valley          4.8  hilly type  autumn_to_winter
#
#    no_of_tourist_attration     states_name  \
# 0                      8.0  andhra pradesh
# 1                      8.0  andhra pradesh
# ...

# %% [markdown]
# # states_name

# %%
df['states_name'].isnull().sum()
# Out:
# 174

# %%
df[df['states_name'].isnull()].head()
# Out:
#                visiting_places  visiting_places_rating  \
# 775                naida caves                     3.5
# 776                nagoa beach                     4.2
# 777  gangeshwar mahadev temple                     3.2
# 778                   diu fort                     4.2
# 779              ghoghla beach                     3.6
#
#      distance_from_city_center cities_name  city_rating   city_type  \
# 775                        1.0         diu          4.1  beach type
# 776                        5.0         diu          4.1  beach type
# 777                        4.0         diu          4.1  beach type
# 778                        1.0         diu          4.1  beach type
# 779                        3.0         diu          4.1  beach type
#
#       city_visit_time  no_of_tourist_attration states_name state_categories  \
# 775  autumn_to_winter                     20.0         NaN              NaN
# ...

# %%
state_name = {
    'diu':'gujarat',
    'daman': 'gujarat',
    'silvassa': 'gujarat',
    'belgaum': 'gujarat',
    'chamoli' : 'uttarakhand',
    'haldwani' :'uttarakhand' ,
    'port blair': 'andaman and nicobar',
    'neil island': 'andaman and nicobar',
    'leh': 'jammu and kashmir',
    'ladakh': 'jammu and kashmir',
    'kargil' :'jammu and kashmir'
}

# %%
 df['states_name'] =df.apply(
    lambda row: state_name.get(row['cities_name'], row['states_name']),
    axis=1
)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                       0
# no_of_tourist_attration               0
# states_name                           0
# state_categories                    174
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %%
df['states_name'].value_counts()
# Out:
# states_name
# kerala                 722
# karnataka              441
# himachal pradesh       439
# maharashtra            404
# rajasthan              357
# gujarat                355
# tamil nadu             337
# uttarakhand            300
# uttar pradesh          284
# mp                     277
# andhra pradesh         248
# jammu and kashmir      234
# west bengal            212
# haryana                150
# assam                  138
# punjab                 133
# bihar                  127
# telangana              116
# odisha                 105
# jharkhand               74
# arunachal pradesh       65
# sikkim                  43
# chhattisgarh            41
# meghalaya               40
# andaman and nicobar     28
# nagaland                20
# manipur                 16
# mizoram                 15
# tripura                 15
# Name: count, dtype: int64

# %% [markdown]
# # state_categories

# %%
df['state_categories'].isnull().sum()
# Out:
# 174

# %%
df[df['state_categories'].isnull()]
# Out:
#                           visiting_places  visiting_places_rating  \
# 775                           naida caves                    3.50
# 776                           nagoa beach                    4.20
# 777             gangeshwar mahadev temple                    3.20
# 778                              diu fort                    4.20
# 779                         ghoghla beach                    3.60
# 780                     sunset point, diu                    3.50
# 781                  st. paul church, diu                    3.50
# 782                   ins khukri memorial                    3.20
# 783                         panikota fort                    3.20
# 784                         zampa gateway                    3.20
# 785                      sea shell museum                    3.20
# 786                            diu museum                    3.20
# 787                     chakratirth beach                    3.10
# ...

# %%
df['state_categories'].value_counts()
# Out:
# state_categories
# cultural_and_heritage_state           2176
# commercial_and_technological_state    1545
# natural_and_scenic_state              1159
# spiritual_and_historical_state         682
# Name: count, dtype: int64

# %%
df[['states_name','state_categories']].value_counts()
# Out:
# states_name        state_categories
# kerala             cultural_and_heritage_state           722
# karnataka          commercial_and_technological_state    441
# himachal pradesh   natural_and_scenic_state              439
# maharashtra        commercial_and_technological_state    404
# rajasthan          cultural_and_heritage_state           357
# tamil nadu         cultural_and_heritage_state           337
# gujarat            commercial_and_technological_state    295
# uttarakhand        natural_and_scenic_state              284
# uttar pradesh      spiritual_and_historical_state        284
# mp                 spiritual_and_historical_state        277
# andhra pradesh     commercial_and_technological_state    248
# west bengal        cultural_and_heritage_state           212
# jammu and kashmir  natural_and_scenic_state              164
# haryana            cultural_and_heritage_state           150
# assam              cultural_and_heritage_state           138
# ...

# %%
state_categorie= {
    'gujarat':'commercial_and_technological_state',
    'uttarakhand':'natural_and_scenic_state',
    'andaman and nicobar':'natural_and_scenic_state',
    'jammu and kashmir':"natural_and_scenic_state"
}

# %%
 df['state_categories'] =df.apply(
    lambda row: state_categorie.get(row['states_name'], row['state_categories']),
    axis=1
)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                       0
# no_of_tourist_attration               0
# states_name                           0
# state_categories                      0
# state_visit_time                    353
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %%
df['state_categories'].value_counts()
# Out:
# state_categories
# cultural_and_heritage_state           2176
# commercial_and_technological_state    1605
# natural_and_scenic_state              1273
# spiritual_and_historical_state         682
# Name: count, dtype: int64

# %% [markdown]
# # state_visit_time

# %%
df['state_visit_time'].isnull().sum()
# Out:
# 353

# %%
df[df['state_visit_time'].isnull()]['states_name'].value_counts()
# Out:
# states_name
# odisha                 105
# jharkhand               74
# jammu and kashmir       70
# gujarat                 60
# andaman and nicobar     28
# uttarakhand             16
# Name: count, dtype: int64

# %%
df[['states_name','state_visit_time']].value_counts()
# Out:
# states_name        state_visit_time
# kerala             winter              722
# karnataka          winter              441
# himachal pradesh   summer              439
# maharashtra        monsoon             404
# rajasthan          winter              357
# tamil nadu         winter              337
# gujarat            winter              295
# uttarakhand        summer              284
# uttar pradesh      winter              284
# mp                 winter              277
# andhra pradesh     winter              248
# west bengal        winter              212
# jammu and kashmir  summer              164
# haryana            winter              150
# assam              spring              138
# punjab             winter              133
# bihar              winter              127
# telangana          winter              116
# arunachal pradesh  summer               65
# sikkim             summer               43
# chhattisgarh       summer               41
# ...

# %%
state_visit_time= {
    'gujarat':'winter',
    'uttarakhand':'summer',
    'andaman and nicobar':'winter',
    'jammu and kashmir':"summer",
    'odisha':'winter',
    'jharkhand':'winter'
}

# %%
 df['state_visit_time'] =df.apply(
    lambda row: state_visit_time.get(row['states_name'], row['state_visit_time']),
    axis=1
)

# %%
df.isnull().sum()
# Out:
# visiting_places                       0
# visiting_places_rating                0
# distance_from_city_center           513
# cities_name                           0
# city_rating                           0
# city_type                             0
# city_visit_time                       0
# no_of_tourist_attration               0
# states_name                           0
# state_categories                      0
# state_visit_time                      0
# visiting_place_summary                3
# visiting_place_tokenized_summary      3
# city_summary                        174
# city_tokenized_summary              174
# best_time_to_visit                  276
# dtype: int64

# %%
df[['states_name','state_visit_time']].value_counts()
# Out:
# states_name          state_visit_time
# kerala               winter              722
# karnataka            winter              441
# himachal pradesh     summer              439
# maharashtra          monsoon             404
# rajasthan            winter              357
# gujarat              winter              355
# tamil nadu           winter              337
# uttarakhand          summer              300
# uttar pradesh        winter              284
# mp                   winter              277
# andhra pradesh       winter              248
# jammu and kashmir    summer              234
# west bengal          winter              212
# haryana              winter              150
# assam                spring              138
# punjab               winter              133
# bihar                winter              127
# telangana            winter              116
# odisha               winter              105
# jharkhand            winter               74
# ...

# %% [markdown]
# # distance_from_city_center

# %%
df['distance_from_city_center'].isnull().sum()
# Out:
# 513

# %%
df[df['distance_from_city_center'].isnull()]['visiting_place_summary'].head(10)
# Out:
# 2      distance 13 km araku chaparai waterfalls dumbr...
# 3      tadimada waterfalls beauty would make fall lov...
# 7      padmapuram gardens known favourite spot among ...
# 28     tu142m aircraft indian navy served 29 years de...
# 34     native tribal community araku valley andhra pr...
# 50     temple lies distance 70 km tirupati constructe...
# 82     tirumala tirupati teppotsavam otherwise called...
# 83     tirumala venkateswara temple along richest tem...
# 106    haailand situated around 19 km vijayawada outs...
# 117    veerabhadra temple located lepakshi village 15...
# Name: visiting_place_summary, dtype: object

# %%
df['distance_from_city_center'].describe()
# Out:
# count    5223.000000
# mean       14.635459
# std        22.468762
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        17.000000
# max       150.000000
# Name: distance_from_city_center, dtype: float64

# %%
pattern = r'(\d+\s*km)'
df['distance_nan'] = df['visiting_place_summary'].str.extract(pattern)

# %%
df['distance_nan'] = df['distance_nan'].str.split('km').str.get(0)

# %%
df['distance_nan_numeric'] = df['distance_nan'].str.extract(r'(\d+)')

df['distance_from_city_center'].fillna(df['distance_nan_numeric'], inplace=True)
# Out:
# C:\Users\HARSHIT JAIN\AppData\Local\Temp\ipykernel_23564\3688176002.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['distance_from_city_center'].fillna(df['distance_nan_numeric'], inplace=True)
# C:\Users\HARSHIT JAIN\AppData\Local\Temp\ipykernel_23564\3688176002.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['13' nan nan nan nan '70' nan nan '19' '15' '5' '4' nan nan '65' nan nan
# ...

# %%
df['distance_from_city_center'] = df['distance_from_city_center'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5736 entries, 0 to 6110
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   visiting_places                   5736 non-null   object
#  1   visiting_places_rating            5736 non-null   float64
#  2   distance_from_city_center         5304 non-null   float64
#  3   cities_name                       5736 non-null   object
#  4   city_rating                       5736 non-null   float64
#  5   city_type                         5736 non-null   object
#  6   city_visit_time                   5736 non-null   object
#  7   no_of_tourist_attration           5736 non-null   float64
#  8   states_name                       5736 non-null   object
#  9   state_categories                  5736 non-null   object
#  10  state_visit_time                  5736 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# visiting_places                        0
# visiting_places_rating                 0
# distance_from_city_center            432
# cities_name                            0
# city_rating                            0
# city_type                              0
# city_visit_time                        0
# no_of_tourist_attration                0
# states_name                            0
# state_categories                       0
# state_visit_time                       0
# visiting_place_summary                 3
# visiting_place_tokenized_summary       3
# city_summary                         174
# city_tokenized_summary               174
# best_time_to_visit                   276
# distance_nan                        4962
# distance_nan_numeric                4962
# dtype: int64

# %%
df[df['distance_from_city_center'].isnull()][['visiting_places','cities_name','distance_from_city_center']].head()
# Out:
#            visiting_places    cities_name  distance_from_city_center
# 3      tadimada waterfalls   araku valley                        NaN
# 7       padmapuram gardens   araku valley                        NaN
# 28  tu 142 aircraft museum  visakhapatnam                        NaN
# 34            itika pongal  visakhapatnam                        NaN
# 82             teppotsavam       tirupati                        NaN

# %%
# not a visiting places

df.drop(index=[34,82,83,141,144,228,231,284,319,383,412,635,1034,1086,1058,1210,1222,1281,1298,1341,1342,1343,1350,1357,1366,1381,1422,1425,
1426,1430,1438,1440,1456,1459,1497,1788,1859,1880,1882,1883,1932,1940,1999,2039,2073,2271,2284,2285,2294,2297,2299,2335,2337,
2338,2368,2401,2409,2439,2457,2469,2478,2548,2549,2550,2663,2664,2665,2666,2667,2734,2763,2920,3151,3171,3335,3368,3468,3474,
3537,3629,3746,3948,4023,4060,4061,4130,4131,4132,4133,4247,4280,4282,4313,4330,4351,4355,4358,4387,4399,4402,4405,4472,4570,
4571,4574,4581,4582,4588,4687,4750,4760,4847,4849,4953,4958,4965,5070,5086,5094,5097,5125,5126,5429,5433,5473,5474,5475,5476,
5510,5511,5557,5716,5754,5854,5855,5867,5875,5881,5893,5902,5931,6017,6020,6021,6024],inplace=True)

# %%
df.shape
# Out:
# (5591, 18)

# %%
df['distance_from_city_center'].isnull().sum()
# Out:
# 288

# %%
df[df['distance_from_city_center'].isnull()][['visiting_places','cities_name','distance_from_city_center']].head()
# Out:
#                     visiting_places        cities_name  \
# 3               tadimada waterfalls       araku valley
# 7                padmapuram gardens       araku valley
# 28           tu 142 aircraft museum      visakhapatnam
# 139                      musi river  ananthagiri hills
# 145  lord anantha padmanabha temple  ananthagiri hills
#
#      distance_from_city_center
# 3                          NaN
# 7                          NaN
# 28                         NaN
# 139                        NaN
# 145                        NaN

# %%
df.drop(index=[6068,6013,6004,6002,5705,5424],inplace=True)

# %%
df.drop(index=[1163],inplace=True)

# %%
df['distance_from_city_center'].isnull().sum()
# Out:
# 281

# %%
df['distance_from_city_center'].describe()
# Out:
# count    5303.000000
# mean       15.158589
# std        27.930113
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        18.000000
# max      1175.000000
# Name: distance_from_city_center, dtype: float64

# %%
df['distance_from_city_center'] = df['distance_from_city_center'].fillna(value=15)

# %%
df.isnull().sum()
# Out:
# visiting_places                        0
# visiting_places_rating                 0
# distance_from_city_center              0
# cities_name                            0
# city_rating                            0
# city_type                              0
# city_visit_time                        0
# no_of_tourist_attration                0
# states_name                            0
# state_categories                       0
# state_visit_time                       0
# visiting_place_summary                 3
# visiting_place_tokenized_summary       3
# city_summary                         163
# city_tokenized_summary               163
# best_time_to_visit                   259
# distance_nan                        4810
# distance_nan_numeric                4810
# dtype: int64

# %%
df.drop(columns=['visiting_place_summary','visiting_place_tokenized_summary','city_summary','city_tokenized_summary',
                'best_time_to_visit','distance_nan','distance_nan_numeric'],inplace=True)

# %%
df.head()
# Out:
#        visiting_places  visiting_places_rating  distance_from_city_center  \
# 0          borra caves                    4.60                       18.0
# 1    katiki waterfalls                    4.10                       14.0
# 2  chaparai waterfalls                    3.90                       13.0
# 3  tadimada waterfalls                    3.57                       15.0
# 4         matsyagundam                    3.57                       32.0
#
#     cities_name  city_rating   city_type   city_visit_time  \
# 0  araku valley          4.8  hilly type  autumn_to_winter
# 1  araku valley          4.8  hilly type  autumn_to_winter
# 2  araku valley          4.8  hilly type  autumn_to_winter
# 3  araku valley          4.8  hilly type  autumn_to_winter
# 4  araku valley          4.8  hilly type  autumn_to_winter
#
#    no_of_tourist_attration     states_name  \
# 0                      8.0  andhra pradesh
# 1                      8.0  andhra pradesh
# ...

# %%
df.shape
# Out:
# (5584, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5584 entries, 0 to 6110
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   visiting_places            5584 non-null   object
#  1   visiting_places_rating     5584 non-null   float64
#  2   distance_from_city_center  5584 non-null   float64
#  3   cities_name                5584 non-null   object
#  4   city_rating                5584 non-null   float64
#  5   city_type                  5584 non-null   object
#  6   city_visit_time            5584 non-null   object
#  7   no_of_tourist_attration    5584 non-null   float64
#  8   states_name                5584 non-null   object
#  9   state_categories           5584 non-null   object
#  10  state_visit_time           5584 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 523.5+ KB

# %%
df.isnull().sum()
# Out:
# visiting_places              0
# visiting_places_rating       0
# distance_from_city_center    0
# cities_name                  0
# city_rating                  0
# city_type                    0
# city_visit_time              0
# no_of_tourist_attration      0
# states_name                  0
# state_categories             0
# state_visit_time             0
# dtype: int64

# %%
df.to_csv('missing_value_imputation_city_state.')
