# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\HARSHIT JAIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df1 = pd.read_csv(r'C:\Users\HARSHIT JAIN\Desktop\data science projects\visit_and_tour_packages_project\datasets\data-preprocessing-city-visiting-places.csv')

# %%
pd.set_option('display.max_rows',None)

# %%
df1.head(10)
# Out:
#           visit_places  rating     city_names  \
# 0          borra caves     4.6   araku valley
# 1    katiki waterfalls     4.1   araku valley
# 2  chaparai waterfalls     3.9   araku valley
# 3  tadimada waterfalls     NaN   araku valley
# 4         matsyagundam     NaN   araku valley
# 5       bheemili beach     NaN   araku valley
# 6        tribal museum     NaN   araku valley
# 7   padmapuram gardens     3.6   araku valley
# 8          borra caves     4.2  visakhapatnam
# 9     submarine museum     3.4  visakhapatnam
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
# 5  bheemili beach vishakhapatnam districts araku ...
# 6  opened 1996 andhra pradesh tourism development...
# ...

# %%
df1.shape
# Out:
# (6057, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6057 entries, 0 to 6056
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   visit_places               6057 non-null   object
#  1   rating                     3448 non-null   float64
#  2   city_names                 5668 non-null   object
#  3   visit_place_summary        5743 non-null   object
#  4   distance_from_city_center  5231 non-null   float64
#  5   tokenized_summary          5743 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 284.1+ KB

# %%
df2 = pd.read_csv(r'C:\Users\HARSHIT JAIN\Desktop\data science projects\visit_and_tour_packages_project\datasets\data-preprocessing-state-visiting-places.csv')

# %%
df2.head(10)
# Out:
#         visit_places  rating  \
# 0       araku valley     4.8
# 1      visakhapatnam     4.4
# 2         amaravathi     4.9
# 3          gandikota     4.5
# 4           tirupati     4.5
# 5         vijayawada     3.9
# 6          anantapur     3.5
# 7          srisailam     4.2
# 8  ananthagiri hills     4.3
# 9            kurnool     4.6
#
#                                  visit_place_summary              best_time  \
# 0  araku valley comparatively unexplored hill sta...  september to february
# 1  visakhapatnam also commonly known vizag one ol...     september to march
# 2  known capital andhra pradesh amaravathi planne...      november to march
# 3  endearingly known ‘ grand canyon india ’ gandi...   november to february
# 4  situated chittoor district andhra pradesh tiru...     september to march
# 5  nestled banks river krishna state andhra prade...     september to march
# 6  anantapuram headquarters anantapur district in...   november to february
# ...

# %%
df1['city_names'].unique().shape
# Out:
# (288,)

# %%
df2['visit_places'].unique().shape
# Out:
# (914,)

# %%
df2.shape
# Out:
# (920, 7)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   visit_places            920 non-null    object
#  1   rating                  776 non-null    float64
#  2   visit_place_summary     920 non-null    object
#  3   best_time               586 non-null    object
#  4   state_name              920 non-null    object
#  5   no_of_turist_attration  510 non-null    float64
#  6   tokenized_summary       920 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 50.4+ KB

# %%
copy_df1 = df1.copy()

# %%
copy_df2 = df2.copy()

# %%
copy_df1.head(10)
# Out:
#           visit_places  rating     city_names  \
# 0          borra caves     4.6   araku valley
# 1    katiki waterfalls     4.1   araku valley
# 2  chaparai waterfalls     3.9   araku valley
# 3  tadimada waterfalls     NaN   araku valley
# 4         matsyagundam     NaN   araku valley
# 5       bheemili beach     NaN   araku valley
# 6        tribal museum     NaN   araku valley
# 7   padmapuram gardens     3.6   araku valley
# 8          borra caves     4.2  visakhapatnam
# 9     submarine museum     3.4  visakhapatnam
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
# 5  bheemili beach vishakhapatnam districts araku ...
# 6  opened 1996 andhra pradesh tourism development...
# ...

# %%
copy_df2.head(10)
# Out:
#         visit_places  rating  \
# 0       araku valley     4.8
# 1      visakhapatnam     4.4
# 2         amaravathi     4.9
# 3          gandikota     4.5
# 4           tirupati     4.5
# 5         vijayawada     3.9
# 6          anantapur     3.5
# 7          srisailam     4.2
# 8  ananthagiri hills     4.3
# 9            kurnool     4.6
#
#                                  visit_place_summary              best_time  \
# 0  araku valley comparatively unexplored hill sta...  september to february
# 1  visakhapatnam also commonly known vizag one ol...     september to march
# 2  known capital andhra pradesh amaravathi planne...      november to march
# 3  endearingly known ‘ grand canyon india ’ gandi...   november to february
# 4  situated chittoor district andhra pradesh tiru...     september to march
# 5  nestled banks river krishna state andhra prade...     september to march
# 6  anantapuram headquarters anantapur district in...   november to february
# ...

# %%
copy_df2.rename(columns={'visit_places':'city_names',
                          'rating':'city_rating',
                          "visit_place_summary":"city_summary",
                          "best_time":"best_time_to_visit",
                          "tokenized_summary":"city_tokenized_summary"},inplace=True)

# %%
copy_df1.head(10)
# Out:
#           visit_places  rating     city_names  \
# 0          borra caves     4.6   araku valley
# 1    katiki waterfalls     4.1   araku valley
# 2  chaparai waterfalls     3.9   araku valley
# 3  tadimada waterfalls     NaN   araku valley
# 4         matsyagundam     NaN   araku valley
# 5       bheemili beach     NaN   araku valley
# 6        tribal museum     NaN   araku valley
# 7   padmapuram gardens     3.6   araku valley
# 8          borra caves     4.2  visakhapatnam
# 9     submarine museum     3.4  visakhapatnam
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
# 5  bheemili beach vishakhapatnam districts araku ...
# 6  opened 1996 andhra pradesh tourism development...
# ...

# %%
copy_df1.rename(columns={"rating":"place_rating",
                        "tokenized_summary":"visit_place_tokenized_summary"},inplace= True)

# %%
copy_df1.head(10)
# Out:
#           visit_places  place_rating     city_names  \
# 0          borra caves           4.6   araku valley
# 1    katiki waterfalls           4.1   araku valley
# 2  chaparai waterfalls           3.9   araku valley
# 3  tadimada waterfalls           NaN   araku valley
# 4         matsyagundam           NaN   araku valley
# 5       bheemili beach           NaN   araku valley
# 6        tribal museum           NaN   araku valley
# 7   padmapuram gardens           3.6   araku valley
# 8          borra caves           4.2  visakhapatnam
# 9     submarine museum           3.4  visakhapatnam
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
# 5  bheemili beach vishakhapatnam districts araku ...
# ...

# %%
copy_df2.head(10)
# Out:
#           city_names  city_rating  \
# 0       araku valley          4.8
# 1      visakhapatnam          4.4
# 2         amaravathi          4.9
# 3          gandikota          4.5
# 4           tirupati          4.5
# 5         vijayawada          3.9
# 6          anantapur          3.5
# 7          srisailam          4.2
# 8  ananthagiri hills          4.3
# 9            kurnool          4.6
#
#                                         city_summary     best_time_to_visit  \
# 0  araku valley comparatively unexplored hill sta...  september to february
# 1  visakhapatnam also commonly known vizag one ol...     september to march
# 2  known capital andhra pradesh amaravathi planne...      november to march
# 3  endearingly known ‘ grand canyon india ’ gandi...   november to february
# 4  situated chittoor district andhra pradesh tiru...     september to march
# 5  nestled banks river krishna state andhra prade...     september to march
# ...

# %%
copy_df1.shape
# Out:
# (6057, 6)

# %%
copy_df2.shape
# Out:
# (920, 7)

# %%
merged_df = pd.merge(copy_df1, copy_df2, how='left', on='city_names')

# %%
merged_df.head(10)
# Out:
#           visit_places  place_rating     city_names  \
# 0          borra caves           4.6   araku valley
# 1    katiki waterfalls           4.1   araku valley
# 2  chaparai waterfalls           3.9   araku valley
# 3  tadimada waterfalls           NaN   araku valley
# 4         matsyagundam           NaN   araku valley
# 5       bheemili beach           NaN   araku valley
# 6        tribal museum           NaN   araku valley
# 7   padmapuram gardens           3.6   araku valley
# 8          borra caves           4.2  visakhapatnam
# 9     submarine museum           3.4  visakhapatnam
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
# 5  bheemili beach vishakhapatnam districts araku ...
# ...

# %%
merged_df.shape
# Out:
# (6117, 12)

# %%
merged_df[merged_df.duplicated()]
# Out:
#                    visit_places  place_rating city_names visit_place_summary  \
# 356      kheti and lajo village           NaN        NaN                 NaN
# 357               khonsa museum           NaN        NaN                 NaN
# 358      namdapha national park           NaN        NaN                 NaN
# 359                        miao           NaN        NaN                 NaN
# 474             district museum           NaN        NaN                 NaN
# 1525                 sissu lake           NaN        NaN                 NaN
# 2202       adventure activities           NaN        NaN                 NaN
# 5075  unokotiswara kal bhairava           NaN        NaN                 NaN
#
#       distance_from_city_center visit_place_tokenized_summary  city_rating  \
# 356                         NaN                           NaN          NaN
# 357                         NaN                           NaN          NaN
# ...

# %%
merged_df.drop_duplicates(inplace=True)

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6117 entries, 0 to 6124
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   visit_places                   6117 non-null   object
#  1   place_rating                   3486 non-null   float64
#  2   city_names                     5736 non-null   object
#  3   visit_place_summary            5811 non-null   object
#  4   distance_from_city_center      5293 non-null   float64
#  5   visit_place_tokenized_summary  5811 non-null   object
#  6   city_rating                    5460 non-null   float64
#  7   city_summary                   5562 non-null   object
#  8   best_time_to_visit             5460 non-null   object
#  9   state_name                     5562 non-null   object
#  10  no_of_turist_attration         5460 non-null   float64
#  11  city_tokenized_summary         5562 non-null   object
# dtypes: float64(4), object(8)
# ...

# %%
merged_df.columns
# Out:
# Index(['visit_places', 'place_rating', 'city_names', 'visit_place_summary',
#        'distance_from_city_center', 'visit_place_tokenized_summary',
#        'city_rating', 'city_summary', 'best_time_to_visit', 'state_name',
#        'no_of_turist_attration', 'city_tokenized_summary'],
#       dtype='object')

# %%
merged_df.isnull().sum()
# Out:
# visit_places                        0
# place_rating                     2631
# city_names                        381
# visit_place_summary               306
# distance_from_city_center         824
# visit_place_tokenized_summary     306
# city_rating                       657
# city_summary                      555
# best_time_to_visit                657
# state_name                        555
# no_of_turist_attration            657
# city_tokenized_summary            555
# dtype: int64

# %%
copy_df1.isnull().sum()
# Out:
# visit_places                        0
# place_rating                     2609
# city_names                        389
# visit_place_summary               314
# distance_from_city_center         826
# visit_place_tokenized_summary     314
# dtype: int64

# %%
copy_df2.isnull().sum()
# Out:
# city_names                  0
# city_rating               144
# city_summary                0
# best_time_to_visit        334
# state_name                  0
# no_of_turist_attration    410
# city_tokenized_summary      0
# dtype: int64

# %%
merged_df.head()
# Out:
#           visit_places  place_rating    city_names  \
# 0          borra caves           4.6  araku valley
# 1    katiki waterfalls           4.1  araku valley
# 2  chaparai waterfalls           3.9  araku valley
# 3  tadimada waterfalls           NaN  araku valley
# 4         matsyagundam           NaN  araku valley
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
#
#    distance_from_city_center  \
# 0                       18.0
# 1                       14.0
# 2                        NaN
# 3                        NaN
# 4                       32.0
#
#                        visit_place_tokenized_summary  city_rating  \
# 0  ['borra', 'caves', 'borra', 'guhalu', 'known',...          4.8
# ...

# %%
merged_df.columns
# Out:
# Index(['visit_places', 'place_rating', 'city_names', 'visit_place_summary',
#        'distance_from_city_center', 'visit_place_tokenized_summary',
#        'city_rating', 'city_summary', 'best_time_to_visit', 'state_name',
#        'no_of_turist_attration', 'city_tokenized_summary'],
#       dtype='object')

# %%
merged_df = merged_df[['visit_places','place_rating','visit_place_summary','visit_place_tokenized_summary',
                       'distance_from_city_center','city_names','city_rating','city_summary','city_tokenized_summary',
                      'no_of_turist_attration','best_time_to_visit','state_name']]

# %%
merged_df.head()
# Out:
#           visit_places  place_rating  \
# 0          borra caves           4.6
# 1    katiki waterfalls           4.1
# 2  chaparai waterfalls           3.9
# 3  tadimada waterfalls           NaN
# 4         matsyagundam           NaN
#
#                                  visit_place_summary  \
# 0  borra caves borra guhalu known native language...
# 1   clear waters river gosthani place goto list area
# 2  distance 13 km araku chaparai waterfalls dumbr...
# 3  tadimada waterfalls beauty would make fall lov...
# 4  popularly known fish pool matsyagundam near pa...
#
#                        visit_place_tokenized_summary  \
# 0  ['borra', 'caves', 'borra', 'guhalu', 'known',...
# 1  ['clear', 'waters', 'river', 'gosthani', 'plac...
# 2  ['distance', '13', 'km', 'araku', 'chaparai', ...
# 3  ['tadimada', 'waterfalls', 'beauty', 'would', ...
# 4  ['popularly', 'known', 'fish', 'pool', 'matsya...
#
#    distance_from_city_center    city_names  city_rating  \
# ...

# %%
merged_df.shape
# Out:
# (6117, 12)

# %%
merged_df.rename(columns={'visit_places':'visiting_places', 'place_rating':'visiting_places_rating',
                          'city_names':'cities_name', 'visit_place_summary':'visiting_place_summary',
                          'visit_place_tokenized_summary':'visiting_place_tokenized_summary',
                          'state_name':'states_name','no_of_turist_attration':'no_of_tourist_attration'},inplace=True)

# %%
merged_df.to_csv('merge_city_state.csv',index = False)
